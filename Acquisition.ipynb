# %% [markdown]
# # Text Acquisition
# CTAWG Febr 2019
#
# Introdcution to basic aspects of data acqusition and data transformation in Python 3, using:
# - Requests
# - ZipFile
# - JSON
# - pickle
#
# The data to be downloaded come from the Open Richly Annotated Cuneiform Corpus ([ORACC](http://oracc.org)). [ORACC](http://oracc.org) data are made available in [JSON](https://www.json.org/) format, all [JSON](https://www.json.org/) files that belong to one [ORACC](http://oracc.org) project are collected in a ZIP file. The data are made available under a [Creative Commons Attribution Non-Commercial Sharealike](https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode) license - no worries about playing around with this data!
#
# We will work with the Old Babylonian Model Contracts ([OBMC](http://oracc.org/obmc)) data set, because this is relatively small and good for demonstration purposes. Old Babylonian model contracts are school texts that teach the proper format and formulary of contracts (house or slave sales, loans, etc.) in Sumerian, dated to approximately 1800 BCE.

# %% [markdown]
# ## Text Acquisition 1: Download a ZIP

# %%
import pandas as pd   
import requests
import zipfile
import tqdm
import json
import os
import errno
import pickle
import re

# %% [markdown]
# # Create Download Directory
# Create a directory called `jsonzip`. If the directory already exists, do nothing.
#
# For the code, see [Stack Overflow](http://stackoverflow.com/questions/18973418/os-mkdirpath-returns-oserror-when-directory-does-not-exist).

# %%
try:
    os.mkdir('jsonzip')
except OSError as exc:
    if exc.errno !=errno.EEXIST:
        raise
    pass

# %% [markdown]
# # Downloading, Chunking
#
# The [requests](http://docs.python-requests.org/en/master/user/quickstart/) library is used for communicating with a server. The `get()` command in `requests` takes a URL as argument and returns a **Response** object.
#
# Since the file we download is a ZIP file, it must be saved as a **binary** file. This is done with the argument `"wb"` in the `open()` command.
#
# In case your file is very large, it may make sense to chunk it (if it is not you can skip that part). The `iter_content()` function in the `requests` package takes care of that.

# %%
url = "http://build-oracc.museum.upenn.edu/json/obmc.zip"
file = "jsonzip/obmc.zip"

CHUNK = 16 * 1024

r = requests.get(url)
if r.status_code == 200:  # if the request is successful
    print("Downloading " + url + " saving as " + file)
    with open(file, 'wb') as f:
        for c in r.iter_content(chunk_size=CHUNK):
            f.write(c)
else:
    print(url + " does not exist.")
# Out:
# Downloading http://build-oracc.museum.upenn.edu/json/obmc.zip saving as jsonzip/obmc.zip

# %% [markdown]
# ## Text Acquisition 2: Scrape
# better ask Jaren ...
#
# Page from the Ebla Digital Archives site [ebda 18](http://ebda.cnr.it/tablet/view/18).

# %%
from bs4 import BeautifulSoup

# %%
url1 = "http://ebda.cnr.it/tablet/view/18"
r1 = requests.get(url1)

# %%
r1.text
# Out:
# '<!DOCTYPE html>\n<html>\n  <head>\n\n    <title>EbDA</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n\n\n    <!-- Bootstrap -->\n    <link href="/static/bootstrap/css/bootstrap.min.css?bootstrap=3.3.7.1.dev1" rel="stylesheet">\n<link href=\'https://fonts.googleapis.com/css?family=Open+Sans:400,400italic\' rel=\'stylesheet\' type=\'text/css\'>\n<link href=\'https://fonts.googleapis.com/css?family=Raleway:400,300,700\' rel=\'stylesheet\' type=\'text/css\'>\n<link href="//cdnjs.cloudflare.com/ajax/libs/animate.css/3.2.0/animate.min.css" rel="stylesheet">\n<link href="/static/css/ebda.css" rel="stylesheet">\n\n\n<meta id="char_index" data-name="ARET 01 0017" value="ARET 01 0017">\n<meta id="tablet_id" data-name="18" value="18">\n\n\n\n  <link rel="shortcut icon" href="/static/favicon.ico">\n  <link rel="stylesheet" type="text/css" href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.css" />\n  <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.js"></script>\n  <script>\n  window.addEventListener("load", function(){\n  window.cookieconsent.initialise({\n    "palette": {\n      "popup": {\n        "background": "#aa0000",\n        "text": "#ffdddd"\n      },\n      "button": {\n        "background": "#ff0000"\n      }\n    },\n    "theme": "edgeless",\n    "position": "bottom-right",\n    "content": {\n      // "href": "http://www.isma.cnr.it/index.php/cookie-policy/"\n      "href": "/policy"\n    }\n  })});\n  </script>\n\n  <!-- Global site tag (gtag.js) - Google Analytics -->\n  <script async src="https://www.googletagmanager.com/gtag/js?id=UA-129150382-1"></script>\n  <script>\n    window.dataLayer = window.dataLayer || [];\n    function gtag(){dataLayer.push(arguments);}\n    gtag(\'js\', new Date());\n\n    gtag(\'config\', \'UA-129150382-1\');\n  </script>\n\n  </head>\n  <body>\n    \n    \n    \n    <nav class="navbar navbar-default navbar-fixed-top">\n\n      <div class="container">\n\n      <!-- Fixed navbar -->\n          <div class="navbar-header">\n            <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#navbar" aria-expanded="false" aria-controls="navbar">\n              <span class="sr-only">Toggle navigation</span>\n              <span class="icon-bar"></span>\n              <span class="icon-bar"></span>\n              <span class="icon-bar"></span>\n            </button>\n            <a class="navbar-brand" href="/index">\n            \n            EbDA\n            </a>\n          </div>\n\n\n          <div id="navbar" class="navbar-collapse collapse">\n            <ul class="nav navbar-nav">\n              <li><a id="index" href="/index">Home</a></li>\n              <li><a id="tabletList" href="/tablet/list">Database</a></li>\n              <li><a id="globalSearch" href="/tablet/search">Search</a></li>\n                  <li class="divider-vertical"></li>\n              <li><a id="biblio" href="/biblio">Bibliography</a></li>\n              <li class="dropdown">\n                <a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button" aria-haspopup="true" aria-expanded="false">Utilities <span class="caret"></span></a>\n                <ul class="dropdown-menu">\n                  <li class="dropdown-header">Indexes</li>\n                  <li><a href="/word/list">Words</a></li>\n                  <li><a href="/value/list">Sign Values</a></li>\n                  <li><a href="/sign/list">Sign Names</a></li>\n                  \n                </ul>\n              </li>\n              \n              \n              \n              \n            </ul>\n\n            \n            <ul class="nav navbar-nav navbar-right">\n              <!-- <li><a href="../navbar-fixed-top/">Fixed top</a></li> -->\n              \n              \n              <li class="dropdown user user-menu">\n                <a href="/login"><i class="glyphicon glyphicon-leaf"></i> Login< ...

# %%
soup = BeautifulSoup(r1.text, "html.parser")
data = soup.find_all('a', attrs={'id' : re.compile(r".*")})
rawdata = [item.contents for item in data]

# %%
l = []
for i in rawdata:
    s = ""
    for item in i:
        s = s+ str(item).strip()
    l.append(s)
l
# Out:
# ['Home',
#  'Database',
#  'Search',
#  'Bibliography',
#  'Corrections',
#  'Words frequency',
#  'Signs frequency',
#  'r.1,1',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.1,2',
#  '2',
#  '<i>gu</i>₂-<i>li</i>-<i>lum</i>',
#  'a-gar₅-gar₅',
#  'ku₃-gi',
#  'r.1,3',
#  '<i>gu</i>₂-<i>za</i>-<i>zi</i>',
#  'r.1,4',
#  'TUŠ.LU₂xTIL',
#  'r.1,5',
#  '2',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '2',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '4',
#  '<i>gu</i>₂-<i>li</i>-<i>lum</i>',
#  'a-gar₅-gar₅',
#  'ku₃-gi-Ⅱ',
#  'r.1,6',
#  '<i>a</i>-<i>šur</i>ᵪ-<i>il</i>',
#  'r.1,7',
#  '<i>wa</i>',
#  'r.1,8',
#  '<i>i</i>-<i>da</i>-<i>ni</i>-<i>ki</i>-<i>mu</i>',
#  'r.1,9',
#  'ugula',
#  'NI-<i>a</i>-NE-<i>in</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.1,10',
#  '2',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '2',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '2',
#  '<i>gu</i>₂-<i>li</i>-<i>lum</i>',
#  'a-gar₅-gar₅',
#  'r.2,1',
#  'ku₃:bar₆-Ⅰ',
#  'r.2,2',
#  'maškim-<i>su</i>₃',
#  'r.2,3',
#  'šu-du₈',
#  'r.2,4',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.2,5',
#  '<i>ma</i>-<i>za</i>-<i>lum</i>-<i>su</i>₃',
#  'r.2,6',
#  '1',
#  'gir₂',
#  'mar-tu',
#  'ku₃-gi',
#  'r.2,7',
#  '<i>su</i>-<i>ma</i>',
#  'r.2,8',
#  '<i>ab</i>₂-<i>šu</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.2,9',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.2,10',
#  '<i>ar</i>-<i>si</i>-<i>ah</i>',
#  'r.2,11',
#  'lu₂',
#  'r.2,12',
#  '<i>en</i>-<i>na</i>-<i>ma</i>-<i>lik</i>',
#  'r.2,13',
#  'NI-<i>a</i>-NE-<i>ig</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.2,14',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.2,15',
#  '<i>ar</i>-<i>si</i>-<i>ah</i>',
#  'r.2,16',
#  '<i>kab</i>-<i>lu</i>₅-<i>ul</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.3,1',
#  '1',
#  'zara₆<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.3,2',
#  '<i>ti</i>-<i>ri</i>₂-<i>ig</i>-<i>da</i>-<i>mu</i>',
#  'r.3,3',
#  'dam',
#  'r.3,4',
#  'en',
#  'r.3,5',
#  '<i>ha</i>-<i>zu</i>-<i>wa</i>-<i>an</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.3,6',
#  'DU-DU',
#  'r.3,7',
#  '<i>kak</i>-<i>mi</i>-<i>um</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.3,8',
#  '1',
#  'gir₂',
#  'mar-tu',
#  '<i>ba</i>-<i>du</i>-<i>u</i>₄',
#  'ku₃-gi',
#  'r.3,9',
#  '<i>du</i>-<i>bi</i>₂-<i>zi</i>-<i>kir</i>',
#  'r.3,10',
#  'lu₂',
#  '<i>hab</i>₂-<i>ra</i>-<i>ar</i>',
#  'r.3,11',
#  'lu₂',
#  'r.3,12',
#  '<i>aš</i>₂-<i>ša</i>-<i>ti</i>-<i>ga</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.3,13',
#  'sa-zaᵪ<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.3,14',
#  '1',
#  'gir₂',
#  'mar-tu',
#  'zu₂',
#  'ku₃-gi',
#  'r.4,1',
#  '<i>i</i>₃-<i>gi</i>',
#  'r.4,2',
#  '1',
#  'gir₂',
#  'mar-tu',
#  '<i>ba</i>-<i>du</i>-<i>u</i>₄',
#  'ku₃:bar₆',
#  'ku₃-gi',
#  'r.4,3',
#  '<i>ma</i>-<i>bu</i>₁₄-<i>ru</i>₁₂',
#  'r.4,4',
#  'lu₂-kar',
#  'r.4,5',
#  '<i>a</i>-<i>da</i>-<i>bi</i>₂-<i>ig</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.4,6',
#  '1',
#  'gir₂',
#  'mar-tu',
#  '<i>ba</i>-<i>du</i>-<i>u</i>₄',
#  'ku₃:bar₆',
#  'ku₃-gi',
#  'r.4,7',
#  '<i>ib</i>-<i>dur</i>-<i>ti</i>-<i>lu</i>',
#  'r.4,8',
#  'lu₂',
#  '<i>a</i>-<i>mur</i>-<i>li</i>-<i>im</i>',
#  'r.4,9',
#  '2',
#  '<i>gu</i>₂-<i>li</i>-<i>lum</i>',
#  'a-gar₅-gar₅',
#  'ku₃-gi',
#  'TAR-2',
#  'r.4,10',
#  '<i>ze</i>₂-<i>da</i>-<i>ar</i>',
#  'r.4,11',
#  'dumu-nita',
#  'r.5,1',
#  '<i>mu</i>-<i>da</i>-NE',
#  'r.5,2',
#  '<i>a</i>-<i>ha</i>-[<i>d</i>]<i>a</i>-<i>mu</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.5,3',
#  '2',
#  '<i>gu</i>₂-<i>li</i>-<i>lum</i>',
#  'a-gar₅-gar₅',
#  'ku₃-gi',
#  'TAR-2',
#  'r.5,4',
#  'lu₂',
#  '<i>za</i>-<i>gu</i>₂-<i>rum</i>₂',
#  'r.5,5',
#  'lu₂',
#  '<i>a</i>-<i>da</i>-<i>si</i>-<i>in</i>',
#  'r.5,6',
#  'i₃-na-sum',
#  'r.5,7',
#  '<i>ir</i>₃-<i>am</i>₆-<i>ma</i>-<i>lik</i>',
#  'r.5,8',
#  '<i>šu</i>-<i>ti</i>-<i>gu</i>₂<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.5,9',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.5,10',
#  '<i>a</i>-<i>du</i>-<i>mu</i>',
#  'r.5,11',
#  'NE.DI',
#  'r.5,12',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.5,13',
#  '<i>daš</i>:ʾ<i>a</i>₃',
#  'r.5,14',
#  '1',
#  'ib₂-Ⅲ',
#  'u₂-hab₂',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.5,15',
#  '<i>ri</i>₂-<i>dam</i>-<i>ma</i>-<i>lik</i>',
#  'r.6,1',
#  'ugula',
#  '<i>šu</i>-<i>ti</i>-<i>gu</i>₂<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.6,2',
#  '1',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.6,3',
#  '<i>ru</i>₁₂-<i>zi</i>-<i>lum</i>',
#  'r.6,4',
#  'šeš',
#  'r.6,5',
#  '<i>a</i>-<i>mu</i>-<i>ra</i>',
#  'r.6,6',
#  '1',
#  '<i><i>GU</i></i>-<i><i>ZI</i></i>-<i><i>TUM</i></i><sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.6,7',
#  '2',
#  '<i>gu</i>₂-<i>li</i>-<i>lum</i>',
#  'a-gar₅-gar₅',
#  'ku₃-gi-Ⅱ',
#  'r.6,8',
#  '1',
#  'gir₂',
#  'mar-tu',
#  'zu₂-ak',
#  'r.6,9',
#  'EN-<i>a</i>-<i>mar</i>',
#  'r.6,10',
#  'E₂xPAP',
#  'r.6,11',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.6,12',
#  '<i>ze</i>₂-<i>da</i>-<i>ar</i>',
#  'r.7,1',
#  '<i>kak</i>-<i>mi</i>-<i>um</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.7,2',
#  'šu-mu-tag₄',
#  'r.7,3',
#  'geštin',
#  'r.7,4',
#  '4',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '4',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.7,5',
#  '<i>bu</i>₁₄-<i>ga</i>-<i>du</i>',
#  'r.7,6',
#  '<i>wa</i>',
#  'r.7,7',
#  '<i>a</i>-<i>ba</i>-<i>nu</i>',
#  'r.7,8',
#  '<i>wa</i>',
#  'r.7,9',
#  '<i>i</i>-<i>ga</i>-<i>li</i>-<i>im</i>',
#  'r.7,10',
#  '<i>wa</i>',
#  'r.7,11',
#  '1',
#  'dumu-nita',
#  'r.7,12',
#  '<i>na</i>-<i>zu</i>₂-<i>u</i>₃',
#  'r.7,13',
#  '<i>ib</i>-<i>al</i>₆<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.7,14',
#  '2',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'maškim-<i>su</i>₃',
#  'r.7,15',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.7,16',
#  '<i>i</i>-<i>ti</i>-<i>ma</i>-<i>lik</i>',
#  'r.7,17',
#  '<i>kak</i>-<i>mi</i>-<i>um</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.8,1',
#  'šu-mu-tag₄',
#  'r.8,2',
#  'geštin',
#  'r.8,3',
#  'a-UD',
#  'r.8,4',
#  '<i>šu</i>-<i>a</i>-<i>da</i>',
#  'r.8,5',
#  'dumu-nita',
#  'r.8,6',
#  '<i>ib</i>-<i>ri</i>₂-<i>um</i>',
#  'r.8,7',
#  '<i>in</i>',
#  'ud',
#  'r.8,8',
#  '[t]u-ra',
#  'r.8,9',
#  '1',
#  '<i><i>GU</i></i>-<i><i>ZI</i></i>-<i><i>TUM</i></i><sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.8,10',
#  '<i>il</i>₂-<i>zi</i>',
#  'r.8,11',
#  'dumu-nita',
#  'r.8,12',
#  'ʾ<i>a</i>₃-<i>daš</i>',
#  'r.8,13',
#  'šu-du₈',
#  'r.8,14',
#  '<i>zi</i>-<i>ba</i>',
#  'r.8,15',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.8,16',
#  '<i>da</i>-<i>na</i>-<i>il</i>',
#  'r.8,17',
#  '<i>ib</i>-<i>al</i>₆<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.8,18',
#  '2',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '2',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.9,1',
#  'i₃-giš-sag',
#  'r.9,2',
#  '<i>mah</i>-<i>ri</i>₂',
#  'r.9,3',
#  '<i>wa</i>',
#  'r.9,4',
#  'LUM-<i>ma</i>-NE',
#  'r.9,5',
#  '2',
#  'dumu-nita',
#  'r.9,6',
#  '<i>ib</i>-<i>dur</i>-<i>i</i>-<i>šar</i>',
#  'r.9,7',
#  'di-ku₅',
#  'r.9,8',
#  '1',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.9,9',
#  '<i>du</i>-<i>bu</i>₃-<i>i</i>-<i>šar</i>',
#  'r.9,10',
#  'dumu-nita',
#  'r.9,11',
#  '<i>il</i>₂-<i>zi</i>',
#  'r.9,12',
#  'lu₂',
#  '<i>du</i>-<i>nu</i>',
#  'r.9,13',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.9,14',
#  '<i>i</i>-<i>sa</i>-<i>ni</i>-<i>ki</i>-<i>mu</i>',
#  'r.9,15',
#  'lu₂',
#  '<i>gu</i>₂-LUM',
#  'r.9,16',
#  'sa-zaᵪ<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.10,1',
#  '1',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.10,2',
#  '<i>wa</i>-<i>na</i>',
#  'r.10,3',
#  'ugula',
#  'surᵪ((ERIN₂))-kunga₂',
#  'r.10,4',
#  '<i>ib</i>-<i>ri</i>₂-<i>um</i>',
#  'r.10,5',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.10,6',
#  '<i>i</i>-<i>na</i>-KUL',
#  'r.10,7',
#  '<i>i</i>-<i>bu</i>₁₆-<i>bu</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.10,8',
#  '1',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.10,9',
#  '<i>šu</i>-<i>ma</i>-<i>lik</i>',
#  'r.10,10',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.10,11',
#  'HAL-<i>za</i>-<i>um</i>',
#  'r.10,12',
#  'NI-<i>ra</i>-<i>ar</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.10,13',
#  'šu-mu-tag₄',
#  'r.11,1',
#  'uduaᵪ',
#  'r.11,2',
#  'en',
#  'r.11,3',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.11,4',
#  '<span class="epnotation text-muted">blank case</span>',
#  'r.11,5',
#  'šu-du₈',
#  'r.11,6',
#  'maškim',
#  'r.11,7',
#  '<i>ha</i>-<i>ra</i>-<i>il</i>',
#  'r.11,8',
#  '1',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.11,9',
#  '<i>i</i>-<i>ti</i>-<i>ma</i>-<i>lik</i>',
#  'r.11,10',
#  '<i>kak</i>-<i>mi</i>-<i>um</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.11,11',
#  '1',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.11,12',
#  '<i>da</i>-NE-<i>lu</i>',
#  'r.11,13',
#  'ugula',
#  '<i>za</i>-<i>ga</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.11,14',
#  '2',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.11,15',
#  'maškim-<i>su</i>₃',
#  'r.11,16',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.12,1',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.12,2',
#  '<i>en</i>-<i>na</i>-<i>ma</i>-<i>lik</i>',
#  'r.12,3',
#  '[<i>a</i>]<i>r</i>-ʾ<i>a</i>₃-NI-<i>ig</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.12,4',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.12,5',
#  '<i>da</i>-NE-<i>ru</i>₁₂',
#  'r.12,6',
#  '<i>ša</i>-<i>nu</i>-<i>gu</i>₂<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.12,7',
#  '2',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'r.12,8',
#  '<i>hu</i>-<i>ma</i>-<i>ra</i>',
#  'r.12,9',
#  '<i>wa</i>',
#  'r.12,10',
#  'UR-<i>ni</i>',
#  'r.12,11',
#  'lu₂-kar',
#  'r.12,12',
#  'šeš-Ⅱ-ib',
#  'r.12,13',
#  'keš₂-da',
#  'r.12,14',
#  'sa-zaᵪ<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'r.12,15',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.1,1',
#  '<i>ib</i>-<i>du</i>-<i>ma</i>-<i>lik</i>',
#  'v.1,2',
#  'kin₅-⸢ak⸣',
#  'v.1,3',
#  'buru₄<sup>m</sup><sup>u</sup><sup>š</sup><sup>e</sup><sup>n</sup><sup></sup>',
#  'v.1,4',
#  '1',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.1,5',
#  '<i><i>KU</i></i>-<i><i>TU</i></i>',
#  'v.1,6',
#  'ugula',
#  '<i>da</i>-<i>mi</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.1,7',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.1,8',
#  'maškim-<i>su</i>₃',
#  'v.1,9',
#  '1',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.1,10',
#  '<i>ma</i>:<i>bu</i>₁₄:<i>ru</i>₁₂',
#  'v.1,11',
#  '<span class="epnotation text-muted">blank case</span>',
#  'v.1,12',
#  'šu-du₈',
#  'v.1,13',
#  '<i>a</i>-<i>da</i>-<i>bi</i>₂-<i>ig</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.1,14',
#  'šu-du₈',
#  'v.1,15',
#  '<i>a</i>-ʾ<i>a</i>₃-<i>lu</i>',
#  'v.1,16',
#  'lu₂',
#  '<i>u</i>₃-<i>ga</i>',
#  'v.1,17',
#  '2',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.2,1',
#  '2',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.2,2',
#  '<i>lu</i>-<i>la</i>-<i>ma</i>-<i>lik</i>',
#  'v.2,3',
#  '<i>wa</i>',
#  'v.2,4',
#  '⸢NI⸣-LUM',
#  'v.2,5',
#  '<i>a</i>-<i>da</i>-<i>bi</i>₂-<i>ig</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.2,6',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.2,7',
#  '<i>ma</i>-<i>u</i>₉-<i>um</i>',
#  'v.2,8',
#  '<i>a</i>-<i>da</i>-<i>bi</i>₂-<i>ig</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.2,9',
#  'e₃',
#  'v.2,10',
#  'nig₂-kaskal',
#  'v.2,11',
#  '1',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.2,12',
#  '<i>ku</i>-<i>bar</i>-<i>ru</i>₁₂',
#  'v.2,13',
#  'maškim',
#  'v.2,14',
#  '<i>en</i>-<i>na</i>-<i>il</i>',
#  'v.2,15',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.2,16',
#  '<i>ti</i>-<i>ru</i>₁₂',
#  'v.2,17',
#  'NE.DI',
#  'v.3,1',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.3,2',
#  '<i>u</i>₃-<i>gu</i>₂-<i>ba</i>₄',
#  'v.3,3',
#  '<i>gar</i>₃-<i>mu</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.3,4',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.3,5',
#  '⸢maškim⸣-[<i>s</i>]<i>u</i>₃',
#  'v.3,6',
#  '⸢2⸣',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.3,7',
#  '<i>ig</i>-<i>bu</i>₃-<i>ul</i>-<i>ma</i>-<i>lik</i>',
#  'v.3,8',
#  '<i>wa</i>',
#  'v.3,9',
#  '<i>ib</i>-<i>hu</i>-<i>ur</i>₂',
#  'v.3,10',
#  'NE.DI',
#  'v.3,11',
#  '2',
#  'ib₂-Ⅲ',
#  'sa₆!!',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'gun₃',
#  'v.3,12',
#  '<i>ig</i>-<i>na</i>-<i>da</i>-<i>ar</i>',
#  'v.3,13',
#  'lu₂',
#  '<span class="epnotation text-muted">blank space at the end of a case</span>',
#  'v.3,14',
#  '<i>wa</i>',
#  'v.3,15',
#  '<i>ib</i>-<i>ga</i>-<i>iš</i>-<i>lu</i>',
#  'v.3,16',
#  'sa-zaᵪ<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.4,1',
#  '1',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.4,2',
#  '<i>du</i>-<i>bi</i>₂-<i>šum</i>',
#  'v.4,3',
#  'lu₂-kar',
#  'v.4,4',
#  '2',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '2',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.4,5',
#  '<i>hal</i>-<i>ra</i>',
#  'v.4,6',
#  '<i>wa</i>',
#  'v.4,7',
#  '<i>i</i>-<i>da</i>-<i>il</i>',
#  'v.4,8',
#  '<i>ab</i>₂-<i>šu</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.4,9',
#  '1',
#  'gada<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'nig₂-la₂-sag',
#  'v.4,10',
#  '<i>gu</i>₂-<i>ra</i>-<i>u</i>₉',
#  'v.4,11',
#  'lu₂-kar',
#  'v.4,12',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.4,13',
#  '<i>ib</i>-<i>ga</i>-<i>iš</i>-<i>lu</i>',
#  'v.4,14',
#  'lu₂',
#  '<i>a</i>-<i>du</i>-⸢<i>ga</i>⸣',
#  'v.5,1',
#  '1',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.5,2',
#  '1',
#  'nig₂-la₂-sag',
#  'v.5,3',
#  '<i>iš</i>₁₁-<i>ar</i>-<i>li</i>-<i>im</i>',
#  'v.5,4',
#  'lu₂-kar',
#  'v.5,5',
#  '1',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.5,6',
#  '<i>iš</i>₁₁-<i>a</i>-<i>ma</i>-<i>lik</i>',
#  'v.5,7',
#  '<i>du</i>-<i>ub</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.5,8',
#  'šu-mu-tag₄',
#  'v.5,9',
#  'geštin',
#  'v.5,10',
#  '1',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '<i>a</i>-<i>mu</i>-<i>ra</i>',
#  'v.5,11',
#  'maškim-<i>su</i>₃',
#  'v.5,12',
#  '1',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '1',
#  'gir₂',
#  'mar-tu',
#  'zu₂-ak',
#  'v.5,13',
#  'nig₂-ba',
#  'v.5,14',
#  '<sup>d</sup><sup>i</sup><sup>n</sup><sup>g</sup><sup>i</sup><sup>r</sup>NI-<i>da</i>-KUL',
#  'v.5,15',
#  'ʾ<i>a</i>₃-<i>ma</i>-<i>du</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.6,1',
#  '<i>in</i>',
#  'ud',
#  'v.6,2',
#  'NE-<i>da</i>-ʾ<i>a</i>₃-<i>dum</i>',
#  'v.6,3',
#  '1',
#  'gir₂',
#  'mar-tu',
#  '<i>ba</i>-<i>du</i>-<i>u</i>₄',
#  'ku₃:bar₆',
#  'ku₃-gi',
#  'v.6,4',
#  '<i>u</i>₃-<i>da</i>-<i>sa</i>',
#  'v.6,5',
#  'di-ku₅',
#  'v.6,6',
#  '1',
#  'gir₂',
#  'mar-tu',
#  '<i>ba</i>-<i>du</i>-<i>u</i>₄',
#  'ku₃:bar₆',
#  'v.6,7',
#  'lu₂',
#  'v.6,8',
#  '<i>u</i>₃-<i>da</i>-<i>sa</i>',
#  'v.6,9',
#  'i₃-na-sum',
#  'v.6,10',
#  '<i>i</i>-<i>bi</i>₂-<i>šum</i>',
#  'v.6,11',
#  'lu₂',
#  '<i>ru</i>₁₂-<i>zi</i>-<i>ma</i>-<i>lik</i>',
#  'v.6,12',
#  'sa-zaᵪ<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.6,13',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.6,14',
#  '<i>du</i>-<i>bi</i>₂-<i>šum</i>',
#  'v.6,15',
#  'lu₂',
#  'v.7,1',
#  'NI-<i>a</i>-<i>mi</i>-<i>gu</i>₂',
#  'v.7,2',
#  'sa-zaᵪ<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.7,3',
#  '1',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.7,4',
#  'i₃-giš-sag',
#  'v.7,5',
#  '<i>iš</i>₁₁-<i>da</i>-<i>mu</i>',
#  'v.7,6',
#  'lu₂',
#  '<i>ig</i>-<i>ri</i>₂-<i>iš</i>',
#  'v.7,7',
#  'sa-zaᵪ<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.7,8',
#  '1',
#  'tug₂-NI.NI',
#  '2',
#  '<i>gu</i>₂-<i>li</i>-<i>lum</i>',
#  'ku₃-gi',
#  'v.7,9',
#  'nig₂-ba',
#  'v.7,10',
#  '<sup>d</sup><sup>i</sup><sup>n</sup><sup>g</sup><sup>i</sup><sup>r</sup>KU-<i>ra</i>',
#  'v.7,11',
#  '<span class="epnotation text-muted">the end of the column is blank</span>',
#  'v.8,1',
#  '1',
#  'zi-ri₂',
#  'siki',
#  'v.8,2',
#  'du₁₁-ga',
#  'v.8,3',
#  'nidba₂',
#  'v.8,4',
#  '<sup>d</sup><sup>i</sup><sup>n</sup><sup>g</sup><sup>i</sup><sup>r</sup>KU-<i>ra</i>',
#  'v.8,5',
#  '1',
#  'KIN',
#  'siki',
#  'v.8,6',
#  'i₃-giš-sag',
#  'v.8,7',
#  '<sup>d</sup><sup>i</sup><sup>n</sup><sup>g</sup><sup>i</sup><sup>r</sup><i>ga</i>-<i>na</i>-<i>na</i>',
#  'v.8,8',
#  '<i>in</i>',
#  'ud',
#  'v.8,9',
#  '<i>a</i>-<i>ba</i>-<i>i</i>',
#  'v.8,10',
#  '10',
#  'KIN',
#  'siki',
#  'v.8,11',
#  'kin₅-ak',
#  'v.8,12',
#  '10',
#  'tug₂-du₈',
#  'lu₂',
#  'v.8,13',
#  '<sup>g</sup><sup>i</sup><sup>š</sup><sup></sup><sup></sup><sup></sup>gigir₂-Ⅱ',
#  'v.8,14',
#  '<i>nu</i>-<i>za</i>-<i>ar</i>',
#  'v.8,15',
#  'šu-ba₄-ti',
#  'v.8,16',
#  'lu₂-<sup>g</sup><sup>i</sup><sup>š</sup><sup></sup><sup></sup><sup></sup>gigir₂-Ⅱ',
#  'v.8,17',
#  '<span class="epnotation text-muted">the end of the column is blank</span>',
#  'v.9,1',
#  '7',
#  '<i><i>GU</i></i>-<i><i>ZI</i></i>',
#  'mug<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '7',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '7',
#  'gir₂',
#  'mar-tu',
#  'zu₂-ak',
#  'v.9,2',
#  'nu-du₁₁',
#  'v.9,3',
#  'DU-DU',
#  'v.9,4',
#  '<i>ib</i>-<i>al</i>₆<sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.9,5',
#  '10',
#  '<i><i>GU</i></i>-<i><i>ZI</i></i>',
#  'mug<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.9,6',
#  'nig₂-sa₁₀',
#  'v.9,7',
#  'nig₂-sa₁₀',
#  'v.9,8',
#  'šu-mu-tag₄',
#  'v.9,9',
#  '1',
#  'zi-ri₂',
#  'siki',
#  'v.9,10',
#  'du₁₁-ga',
#  'v.9,11',
#  'nidba₂',
#  'v.9,12',
#  '<sup>d</sup><sup>i</sup><sup>n</sup><sup>g</sup><sup>i</sup><sup>r</sup><i>ga</i>-<i>mi</i>-<i>iš</i>',
#  'v.9,13',
#  '4',
#  '<i><i>GU</i></i>-<i><i>ZI</i></i>',
#  'mug<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  '4',
#  'ib₂-Ⅱ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.10,1',
#  '<i>sur</i>₃((HIMAŠ))-<i>si</i>',
#  'v.10,2',
#  'lu₂',
#  '<i>ba</i>₄-<i>a</i>-<i>sa</i>',
#  'v.10,3',
#  '<i>en</i>-<i>na</i>-NI',
#  'v.10,4',
#  'lu₂',
#  'BAD-E₂',
#  'v.10,5',
#  '<i>en</i>-<i>na</i>-NI',
#  'v.10,6',
#  'lu₂',
#  '<i>gar</i>₃-<i>ra</i>-<i>nu</i>',
#  'v.10,7',
#  '<i>ir</i>₃-<i>ga</i>-<i>bu</i>₃',
#  'v.10,8',
#  'lu₂',
#  '<i>du</i>-<i>bi</i>₂-<i>šum</i>',
#  'v.10,9',
#  '<i><i>NA</i></i>-<i><i>SE</i></i>₁₁',
#  'v.10,10',
#  '<i>ša</i>-<i>ba</i>₄',
#  'v.10,11',
#  '<i>kab</i>-<i>lu</i>₅-<i>ul</i><sup>k</sup><sup>i</sup><sup></sup><sup></sup><sup></sup><sup></sup>',
#  'v.10,12',
#  '<span class="epnotation text-muted">the entire column is blank</span>',
#  'v.11,1',
#  '⸢AN⸣.ŠE₃.GU₂',
#  '2',
#  '<i><i>GU</i></i>-<i><i>ZI</i></i>-<i><i>TUM</i></i><sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.11,2',
#  '1',
#  'zara₆<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.11,3',
#  '10-6',
#  'aktum<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.11,4',
#  '10-6',
#  'gu-dul₃<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'gada<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.11,5',
#  '10-2',
#  'SAL<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.11,6',
#  '1',
#  'tug₂-NI.NI',
#  'v.11,7',
#  '2',
#  'nig₂-la₂-sag',
#  'v.11,8',
#  '10-4',
#  'ib₂-Ⅲ',
#  'sa₆',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.11,9',
#  '40-6',
#  'ib₂-Ⅲ',
#  'gun₃',
#  '<sup>t</sup><sup>u</sup><sup>g</sup><sup>₂</sup><sup></sup><sup></sup>',
#  'v.11,10',
#  '<span class="epnotation text-muted">blank space at the beginning of a case</span>',
#  'šu-nigin₂',
#  '{x}',
#  '50',
#  'tug₂-tug₂',
#  'le,1',
#  'iti',
#  '<i>gi</i>-NI',
#  'Search Word<span aria-hidden="true" class="glyphicon glyphicon-new-window"></span>']

# %% [markdown]
# ## Text Acquisition 3: Click a Button
#
# Some web sites provide an export option. Go to [BDTNS](http://bdtns.filol.csic.es/) go to drop-down menu "Catalogue and Transliterations" and choose "Search". In "Word and Grapheme Strings" search for "gu2-bir5" (with the double quotation marks). The word gu₂-bir₅ means "locust neck" and is (rarely) used as a qualification of bronze (presumably meaning: greenish). You will get a list of two texts and you can click "Export" to get a list of export options.

# %% [markdown]
# # Back to ORACC: Inspect the ZIP File
#
# The function `ZipFile()` in the [zipfile](https://docs.python.org/3/library/zipfile.html) library takes as argument the name of a ZIP file. It returns the Zipfile object `z`. The command `namelist()` returns a list with all the filenames of the files in the ZIP.
#
# To extract all the files from the ZIP file use `.extractall()` as in:
# ```python3
# z = zipfile.ZipFile(file)
# z.extractall()
# ```
#
# In this demonstration we will not do so - we will read and manipulate the data from the files that we need directly from the ZIP file without saving the extracted files - thus saving some disk space.

# %%
z = zipfile.ZipFile(file)
z.namelist()
# Out:
# ['obmc/',
#  'obmc/gloss-qpn-x-months.json',
#  'obmc/index-tra.json',
#  'obmc/gloss-qpn-x-places.json',
#  'obmc/index-qpn-x-temple.json',
#  'obmc/index-qpn-x-months.json',
#  'obmc/index-sux.json',
#  'obmc/gloss-qpn-x-divine.json',
#  'obmc/index-qpn-x-divine.json',
#  'obmc/obmc-portal.json',
#  'obmc/gloss-qpn-x-temple.json',
#  'obmc/corpus.json',
#  'obmc/index-qpn-x-places.json',
#  'obmc/index-lem.json',
#  'obmc/gloss-qpn-x-waters.json',
#  'obmc/sortcodes.json',
#  'obmc/corpusjson/',
#  'obmc/corpusjson/P411563.json',
#  'obmc/corpusjson/P230698.json',
#  'obmc/corpusjson/P230726.json',
#  'obmc/corpusjson/P230723.json',
#  'obmc/corpusjson/P230664.json',
#  'obmc/corpusjson/P251564.json',
#  'obmc/corpusjson/P230801.json',
#  'obmc/corpusjson/P229699.json',
#  'obmc/corpusjson/P230144.json',
#  'obmc/corpusjson/P230668.json',
#  'obmc/corpusjson/P230753.json',
#  'obmc/corpusjson/X000008.json',
#  'obmc/corpusjson/P273797.json',
#  'obmc/corpusjson/P230746.json',
#  'obmc/corpusjson/P230734.json',
#  'obmc/corpusjson/P230751.json',
#  'obmc/corpusjson/P251517.json',
#  'obmc/corpusjson/P229764.json',
#  'obmc/corpusjson/P388287.json',
#  'obmc/corpusjson/P229997.json',
#  'obmc/corpusjson/P388376.json',
#  'obmc/corpusjson/P229564.json',
#  'obmc/corpusjson/P230649.json',
#  'obmc/corpusjson/P230676.json',
#  'obmc/corpusjson/P231446.json',
#  'obmc/corpusjson/P230280.json',
#  'obmc/corpusjson/P252260.json',
#  'obmc/corpusjson/P252326.json',
#  'obmc/corpusjson/P230428.json',
#  'obmc/corpusjson/P231090.json',
#  'obmc/corpusjson/P289409.json',
#  'obmc/corpusjson/P253576.json',
#  'obmc/corpusjson/P252290.json',
#  'obmc/corpusjson/P388580.json',
#  'obmc/corpusjson/X000012.json',
#  'obmc/corpusjson/P231448.json',
#  'obmc/corpusjson/P230794.json',
#  'obmc/corpusjson/P230665.json',
#  'obmc/corpusjson/P230721.json',
#  'obmc/corpusjson/P273878.json',
#  'obmc/corpusjson/P229940.json',
#  'obmc/corpusjson/P252271.json',
#  'obmc/corpusjson/P230632.json',
#  'obmc/corpusjson/P230624.json',
#  'obmc/corpusjson/P230625.json',
#  'obmc/corpusjson/P229621.json',
#  'obmc/corpusjson/P230728.json',
#  'obmc/corpusjson/P231450.json',
#  'obmc/corpusjson/P459215.json',
#  'obmc/corpusjson/P200932.json',
#  'obmc/corpusjson/P230715.json',
#  'obmc/corpusjson/P230667.json',
#  'obmc/corpusjson/P230765.json',
#  'obmc/corpusjson/P230776.json',
#  'obmc/corpusjson/P230620.json',
#  'obmc/corpusjson/P253216.json',
#  'obmc/corpusjson/P388377.json',
#  'obmc/corpusjson/P252249.json',
#  'obmc/corpusjson/P230212.json',
#  'obmc/corpusjson/P230662.json',
#  'obmc/corpusjson/P252262.json',
#  'obmc/corpusjson/P248006.json',
#  'obmc/corpusjson/P229969.json',
#  'obmc/corpusjson/P230618.json',
#  'obmc/corpusjson/P229318.json',
#  'obmc/corpusjson/P390404.json',
#  'obmc/corpusjson/P230722.json',
#  'obmc/corpusjson/P388305.json',
#  'obmc/corpusjson/P230727.json',
#  'obmc/corpusjson/P230634.json',
#  'obmc/corpusjson/P251516.json',
#  'obmc/corpusjson/P230659.json',
#  'obmc/corpusjson/P230806.json',
#  'obmc/corpusjson/P230464.json',
#  'obmc/corpusjson/P229216.json',
#  'obmc/corpusjson/P252010.json',
#  'obmc/corpusjson/P230420.json',
#  'obmc/corpusjson/P230580.json',
#  'obmc/corpusjson/X000011.json',
#  'obmc/corpusjson/P230775.json',
#  'obmc/corpusjson/P252280.json',
#  'obmc/corpusjson/P342643.json',
#  'obmc/corpusjson/P230661.json',
#  'obmc/corpusjson/P229743.json',
#  'obmc/corpusjson/P227962.json',
#  'obmc/corpusjson/P230713.json',
#  'obmc/corpusjson/P251568.json',
#  'obmc/corpusjson/P228140.json',
#  'obmc/corpusjson/P230558.json',
#  'obmc/corpusjson/P230627.json',
#  'obmc/corpusjson/P230711.json',
#  'obmc/corpusjson/P230754.json',
#  'obmc/corpusjson/P342646.json',
#  'obmc/corpusjson/P229931.json',
#  'obmc/corpusjson/P229278.json',
#  'obmc/corpusjson/P250815.json',
#  'obmc/corpusjson/P228991.json',
#  'obmc/corpusjson/P254010.json',
#  'obmc/corpusjson/X000007.json',
#  'obmc/corpusjson/P230643.json',
#  'obmc/corpusjson/X000001.json',
#  'obmc/corpusjson/P230644.json',
#  'obmc/corpusjson/P229038.json',
#  'obmc/corpusjson/P230651.json',
#  'obmc/corpusjson/X000013.json',
#  'obmc/corpusjson/P252274.json',
#  'obmc/corpusjson/P230793.json',
#  'obmc/corpusjson/P230642.json',
#  'obmc/corpusjson/P227988.json',
#  'obmc/corpusjson/P368906.json',
#  'obmc/corpusjson/P230591.json',
#  'obmc/corpusjson/P231449.json',
#  'obmc/corpusjson/P255081.json',
#  'obmc/corpusjson/P229702.json',
#  'obmc/corpusjson/P230677.json',
#  'obmc/corpusjson/P231451.json',
#  'obmc/corpusjson/X000002.json',
#  'obmc/corpusjson/P229411.json',
#  'obmc/corpusjson/P388288.json',
#  'obmc/corpusjson/P368911.json',
#  'obmc/gloss-sux.json',
#  'obmc/gloss-qpn.json',
#  'obmc/index-txt.json',
#  'obmc/index-qpn-x-people.json',
#  'obmc/metadata.json',
#  'obmc/index-qpn.json',
#  'obmc/catalogue.json',
#  'obmc/gloss-qpn-x-people.json',
#  'obmc/index-cat.json',
#  'obmc/index-qpn-x-waters.json']

# %% [markdown]
# # The Files
#
# The text data is contained in the files in the directory `obmc/corpusjson`. We will look at that at a later stage. The catalogue data is contained in the file `obmc/catalogue.json`. We will inspect this file.
#
# The `zipfile` function `read()` takes as its argument a file in a ZIP archive and returns a string.
#
# If you know the encoding, it is useful to add that with the `decode()` function - in particular for Windows machines. Windows has its own default encoding scheme which may wreck your file.

# %%
cat_j = "obmc/catalogue.json"
st = z.read(cat_j).decode("utf8")
st
# Out:
# '{\n  "type": "catalogue",\n  "project": "obmc",\n  "source": "http://oracc.org/obmc",\n  "license": "This data is released under the CC0 license",\n  "license-url": "https://creativecommons.org/publicdomain/zero/1.0/",\n  "more-info": "http://oracc.org/doc/opendata/",\n  "UTC-timestamp": "2019-02-05T21:57:40",\n  "members": {\n    "P200931": {\n      "langs": "0x02000000",\n      "project": "obmc",\n      "author": "Limet, Henri",\n      "collection": "Musées royaux d\'Art et d\'Histoire, Brussels, Belgium",\n      "genre": "School",\n      "id_text": "P200931",\n      "language": "Sumerian",\n      "museum_no": "MRAH O.0118",\n      "object_preservation": "--",\n      "object_type": "tablet",\n      "period": "Old Babylonian",\n      "primary_publication": "Akkadica 117 015 O.118",\n      "provenience": "uncertain",\n      "publication_date": "2000",\n      "publication_history": "Speleers, Louis, RIAA (1925) 047",\n      "subgenre": "Type II Tablet",\n      "subgenre_remarks": "Obv: model contract; rev. unreadable",\n      "designation": "Akkadica 117 015 O.118",\n      "supergenre": "LIT",\n      "xproject": "CDLI",\n      "uri": "http://cdli.ucla.edu/P200931",\n      "public": "no",\n      "images": []\n    },\n    "P200932": {\n      "langs": "0x02000000",\n      "project": "obmc",\n      "author": "Limet, Henri",\n      "collection": "Musées royaux d\'Art et d\'Histoire, Brussels, Belgium",\n      "genre": "School",\n      "id_text": "P200932",\n      "language": "Sumerian",\n      "museum_no": "MRAH O.0119",\n      "object_type": "tablet",\n      "period": "Old Babylonian",\n      "primary_publication": "Akkadica 117 015 O.119",\n      "provenience": "uncertain",\n      "publication_date": "2000",\n      "publication_history": "Speleers, Louis, RIAA (1925) 049",\n      "subgenre": "Type III Tablet",\n      "subgenre_remarks": "Model contract",\n      "text_remarks": "Manumission of a male slave; cf. Akkadica 117 016 O.120, BM 080491 and Edubba 9 29.",\n      "designation": "Akkadica 117 015 O.119",\n      "supergenre": "LIT",\n      "xproject": "CDLI",\n      "uri": "http://cdli.ucla.edu/P200932",\n      "public": "no",\n      "images": [],\n      "trans": [\n        "en"\n      ]\n    },\n    "P200933": {\n      "langs": "0x02000000",\n      "project": "obmc",\n      "author": "Limet, Henri",\n      "collection": "Musées royaux d\'Art et d\'Histoire, Brussels, Belgium",\n      "genre": "School",\n      "id_text": "P200933",\n      "language": "Sumerian",\n      "museum_no": "MRAH O.120",\n      "object_type": "tablet",\n      "period": "Old Babylonian",\n      "primary_publication": "Akkadica 117 016 O.120",\n      "provenience": "uncertain",\n      "publication_date": "2000",\n      "publication_history": "Speleers, Louis, RIAA 045",\n      "subgenre": "Type III Tablet",\n      "subgenre_remarks": "Model contract",\n      "text_remarks": "Manumission of a male slave; cf. Akkadica 117 015 O.119, BM 080491 and Edubba 9 29.",\n      "designation": "Akkadica 117 016 O.120",\n      "supergenre": "LIT",\n      "xproject": "CDLI",\n      "uri": "http://cdli.ucla.edu/P200933",\n      "public": "no",\n      "images": []\n    },\n    "P227953": {\n      "langs": "0x02000000",\n      "project": "obmc",\n      "author": "Chiera, Edward",\n      "collection": "University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA",\n      "genre": "School",\n      "id_text": "P227953",\n      "language": "Sumerian",\n      "museum_no": "CBS 04803 + CBS 06591 + CBS 05962",\n      "object_type": "tablet",\n      "period": "Old Babylonian",\n      "primary_publication": "OIP 011, 105 + 109 + 148",\n      "provenience": "Nippur",\n      "publication_date": "1929",\n      "publication_history": "MSL 12, 029 L + 031 Y\'; MSL 05, 169 (on OIP 011, 148)",\n      "subgenre": "Type II Tablet",\n      "subgenre_remarks": "Obv: model contract; rev: OB Nippur Lu",\n      "text_remarks": "Sale of a field",\n      "de ...

# %% [markdown]
# # JSON
#
# This is a JSON file and the data become easier to read and manipulate if we transform it into a proper JSON object with the `json` library with the `load()` function. The function `load()` takes a file as argument, the sister-function `loads()` is used for striungs. Since the output of the `read()` command in `zipfile` is a string, we use `loads()`.

# %%
cat = json.loads(st)
cat
# Out:
# {'type': 'catalogue',
#  'project': 'obmc',
#  'source': 'http://oracc.org/obmc',
#  'license': 'This data is released under the CC0 license',
#  'license-url': 'https://creativecommons.org/publicdomain/zero/1.0/',
#  'more-info': 'http://oracc.org/doc/opendata/',
#  'UTC-timestamp': '2019-02-05T21:57:40',
#  'members': {'P200931': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Limet, Henri',
#    'collection': "Musées royaux d'Art et d'Histoire, Brussels, Belgium",
#    'genre': 'School',
#    'id_text': 'P200931',
#    'language': 'Sumerian',
#    'museum_no': 'MRAH O.0118',
#    'object_preservation': '--',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'Akkadica 117 015 O.118',
#    'provenience': 'uncertain',
#    'publication_date': '2000',
#    'publication_history': 'Speleers, Louis, RIAA (1925) 047',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev. unreadable',
#    'designation': 'Akkadica 117 015 O.118',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P200931',
#    'public': 'no',
#    'images': []},
#   'P200932': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Limet, Henri',
#    'collection': "Musées royaux d'Art et d'Histoire, Brussels, Belgium",
#    'genre': 'School',
#    'id_text': 'P200932',
#    'language': 'Sumerian',
#    'museum_no': 'MRAH O.0119',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'Akkadica 117 015 O.119',
#    'provenience': 'uncertain',
#    'publication_date': '2000',
#    'publication_history': 'Speleers, Louis, RIAA (1925) 049',
#    'subgenre': 'Type III Tablet',
#    'subgenre_remarks': 'Model contract',
#    'text_remarks': 'Manumission of a male slave; cf. Akkadica 117 016 O.120, BM 080491 and Edubba 9 29.',
#    'designation': 'Akkadica 117 015 O.119',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P200932',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P200933': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Limet, Henri',
#    'collection': "Musées royaux d'Art et d'Histoire, Brussels, Belgium",
#    'genre': 'School',
#    'id_text': 'P200933',
#    'language': 'Sumerian',
#    'museum_no': 'MRAH O.120',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'Akkadica 117 016 O.120',
#    'provenience': 'uncertain',
#    'publication_date': '2000',
#    'publication_history': 'Speleers, Louis, RIAA 045',
#    'subgenre': 'Type III Tablet',
#    'subgenre_remarks': 'Model contract',
#    'text_remarks': 'Manumission of a male slave; cf. Akkadica 117 015 O.119, BM 080491 and Edubba 9 29.',
#    'designation': 'Akkadica 117 016 O.120',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P200933',
#    'public': 'no',
#    'images': []},
#   'P227953': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P227953',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 04803 + CBS 06591 + CBS 05962',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'OIP 011, 105 + 109 + 148',
#    'provenience': 'Nippur',
#    'publication_date': '1929',
#    'publication_history': "MSL 12, 029 L + 031 Y'; MSL 05, 169 (on OIP 011, 148)",
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Lu',
#    'text_remarks': 'Sale of a field',
#    'designation': 'OIP 011, 105 + 109 + 148',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P227953'},
#   'P227955': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P227955',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 04805',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'OIP 011, 030',
#    'provenience': 'Nippur',
#    'publication_date': '1929',
#    'publication_history': 'MSL 13, 092 B',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: Nigga',
#    'text_remarks': 'Silver loans',
#    'designation': 'OIP 011, 030',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P227955',
#    'public': 'no',
#    'images': []},
#   'P227962': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P227962',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 04813 + CBS 06853',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'uncertain',
#    'subgenre': 'Type I or II Tablet',
#    'subgenre_remarks': 'Model contracts',
#    'text_remarks': 'Barley loans',
#    'designation': 'CBS 04813 + CBS 06853',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P227962',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P227972': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P227972',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 04826',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'OIP 011, p. 014, CBS 04826 (unpub. dup.)',
#    'provenience': 'Nippur',
#    'publication_date': '1929',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ura 4',
#    'text_remarks': 'Rent of a field',
#    'designation': 'OIP 011, p. 014, CBS 04826 (unpub. dup.)',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P227972',
#    'public': 'no',
#    'images': []},
#   'P227988': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P227988',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 04846',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'OIP 011, 096',
#    'provenience': 'Nippur',
#    'publication_date': '1929',
#    'publication_history': 'MSL 7, 179 (V20)',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ura 2',
#    'text_remarks': 'Two barley loans',
#    'designation': 'OIP 011, 096',
#    'surface_preservation': '--',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P227988',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P228140': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P228140',
#    'language': 'Sumerian',
#    'museum_no': 'N 2469',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre_remarks': 'Model contract',
#    'text_remarks': 'Manumission of a female slave; cf. TMH 11, 01, CBS 08437, CBS 01206, MS 4979, N 0950, N 4075 and UM 29-15-617.',
#    'designation': 'N 2469',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P228140',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P228267': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P228267',
#    'language': 'Sumerian',
#    'museum_no': 'N 4541',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: not preserved',
#    'designation': 'N 4541',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P228267',
#    'public': 'no',
#    'images': []},
#   'P228489': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P228489',
#    'language': 'Sumerian',
#    'museum_no': 'N 5544',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 271',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: not preserved',
#    'text_remarks': 'Barley loan',
#    'designation': 'N 5544',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P228489',
#    'public': 'no',
#    'images': []},
#   'P228766': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Peterson, Jeremiah',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P228766',
#    'language': 'Sumerian',
#    'museum_no': 'UM 29-16-541',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'BPOA 09, 257',
#    'provenience': 'Nippur',
#    'publication_date': '2011',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: Proverb Collection 3; rev: model contract',
#    'text_remarks': 'Barley loans',
#    'designation': 'BPOA 09, 257',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P228766',
#    'public': 'no',
#    'images': []},
#   'P228782': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P228782',
#    'language': 'Sumerian',
#    'museum_no': 'UM 29-16-583',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type III Tablet',
#    'subgenre_remarks': 'Model contract',
#    'text_remarks': 'Real estate (?)',
#    'designation': 'UM 29-16-583',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P228782',
#    'public': 'no',
#    'images': []},
#   'P228991': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P228991',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 05912 + N 4966',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'PBS 11/1, 040',
#    'provenience': 'Nippur',
#    'publication_date': '1916-1919',
#    'publication_history': 'MSL 14, 25 Hh',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ea',
#    'text_remarks': 'Barley loan',
#    'designation': 'PBS 11/1, 040',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P228991',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P229038': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Spada, Gabriella',
#    'citation': 'Civil, MSL 14, 029 Lf',
#    'collection': 'Hilprecht-Sammlung, University of Jena, Germany',
#    'genre': 'School',
#    'id_text': 'P229038',
#    'language': 'Sumerian',
#    'museum_no': 'HS 1607 + HS 2946',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'TMH 11, 09',
#    'provenience': 'Nippur',
#    'publication_date': '2018',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ea',
#    'text_remarks': 'Division of inheritance with supporting clause.',
#    'designation': 'TMH 11, 09',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229038',
#    'trans': ['en']},
#   'P229160': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229160',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 05873',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'uncertain',
#    'publication_history': 'OIP 011, p. 15 (unpub. dup.)',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur ki-ulutin-bi-še3',
#    'text_remarks': 'Real estate',
#    'designation': 'CBS 05873',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229160',
#    'public': 'no',
#    'images': []},
#   'P229166': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Veldhuis, Niek',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229166',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 06098 + N 3960 + N 5128',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'EEN 061, CBS 06098',
#    'provenience': 'Nippur',
#    'publication_date': '1997',
#    'publication_history': 'Veldhuis JAOS 120, 385-386',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contracts; rev: OB Nippur Ura 1',
#    'text_remarks': 'Two sales of a house; cf. CBS 06098; OIP 011, 249; PBS 12, 23; CBS 13934; N 4073; N 4703; 5334',
#    'designation': 'EEN 061, CBS 06098',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229166',
#    'public': 'no',
#    'images': []},
#   'P229216': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Veldhuis EEN, 302',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229216',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 06542',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'OIP 011, p. 15 (unpub. dup.)',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; Rev: OB Nippur Ura 1',
#    'text_remarks': 'Barley loan',
#    'designation': 'CBS 06542',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229216',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P229278': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Reiner &amp; Civil, MSL 11, 095 Q1',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229278',
#    'language': 'Sumerian',
#    'museum_no': 'N 5350',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 270',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ura 5',
#    'text_remarks': 'Rent of commercial property; cf. CBS 03855+UM 29-16-243+N 5901',
#    'designation': 'N 5350',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229278',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P229318': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'citation': 'Veldhuis EEN, 60; Veldhuis, JAOS 120, 385',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229318',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 06527',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'OIP 011, 249',
#    'provenience': 'Nippur',
#    'publication_date': '1929',
#    'publication_history': 'MSL 11, 095 L1; MSL 10, 120 F',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ura 5',
#    'text_remarks': 'Sale of a real estate; cf. EEN 061, CBS 06098; PBS 12, 23; CBS 13934; N 4073; N 4783; N 5334',
#    'designation': 'OIP 011, 249',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229318',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P229326': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229326',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 06530',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'OIP 011, 225',
#    'provenience': 'Nippur',
#    'publication_date': '1929',
#    'publication_history': 'MSL 11, 094 W',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ura 5',
#    'text_remarks': 'Sale of ...',
#    'designation': 'OIP 011, 225',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229326',
#    'public': 'no',
#    'images': []},
#   'P229365': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Reiner &amp; Civil, MSL 11, 112 I1',
#    'collection': 'Oriental Institute, University of Chicago, Chicago, Illinois, USA',
#    'excavation_no': '3N-T0920y',
#    'genre': 'School',
#    'id_text': 'P229365',
#    'language': 'Sumerian',
#    'museum_no': 'A 33510',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'photo Lieberman Misc. 3',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: OB Nippur Ura 6; rev: model contract',
#    'designation': 'A 33510',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229365'},
#   'P229384': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Civil, MSL 14, 018 Ah',
#    'collection': 'Arkeoloji Müzeleri, Istanbul, Turkey',
#    'genre': 'School',
#    'id_text': 'P229384',
#    'language': 'Sumerian',
#    'museum_no': 'Ist Ni 03949',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'photo Lieberman P-Ea Istanbul',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ea',
#    'designation': 'Ist Ni 03949',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229384'},
#   'P229387': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Civil, MSL 14, 018 An',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229387',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 15210',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ea',
#    'designation': 'CBS 15210',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229387',
#    'public': 'no',
#    'images': []},
#   'P229411': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Civil, MSL 14, 020 Db',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229411',
#    'language': 'Sumerian',
#    'museum_no': 'N 5248',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 101',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ea',
#    'text_remarks': 'Two silver loans',
#    'designation': 'N 5248',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229411',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P229414': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Civil, MSL 14, 020 Cl',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229414',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 15225',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ea',
#    'text_remarks': 'Fields',
#    'designation': 'CBS 15225',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229414',
#    'public': 'no',
#    'images': []},
#   'P229428': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Civil, MSL 14, 021 Ds',
#    'collection': 'Arkeoloji Müzelerei, Istanbul, Turkey',
#    'genre': 'School',
#    'id_text': 'P229428',
#    'language': 'Sumerian',
#    'museum_no': 'Ist Ni 03775',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'photo Lieberman P-Ea Istanbul',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ea',
#    'designation': 'Ist Ni 03775',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229428'},
#   'P229443': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Poebel, Arno',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229443',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 14006',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'PBS 05, 128',
#    'provenience': 'Nippur',
#    'publication_date': '1914',
#    'publication_history': 'MSL 14, 23 Fd',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: Ob Nippur Ea',
#    'text_remarks': 'Silver loan (?)',
#    'designation': 'PBS 05, 128',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229443',
#    'public': 'no',
#    'images': []},
#   'P229564': {'langs': '0x02000000',
#    'project': 'obmc',
#    'accession_no': 'newpenn',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 014 D1',
#    'collection': 'Oriental Institute, University of Chicago, Chicago, Illinois, USA',
#    'excavation_no': '3N-T0163',
#    'genre': 'School',
#    'id_text': 'P229564',
#    'language': 'Sumerian',
#    'museum_no': 'A 30173',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi 1',
#    'text_remarks': 'Barley loans (cf. HS 11, 06; CBS 10288; N 1326)',
#    'designation': 'A 30173',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229564',
#    'trans': ['en']},
#   'P229567': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 014 F1',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229567',
#    'language': 'Sumerian',
#    'museum_no': 'N 6041 + N 6049 + UM 29-16-195',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type I Tablet',
#    'subgenre_remarks': 'Model contracts',
#    'text_remarks': 'Two barley loans; three silver loans; one sale of a house; three rents of a field.',
#    'designation': 'N 6041 + N 6049 + UM 29-16-195',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229567',
#    'public': 'no',
#    'images': []},
#   'P229570': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 014 J1',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229570',
#    'language': 'Sumerian',
#    'museum_no': 'N 4976',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 90',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi 1',
#    'text_remarks': 'A slave as a pledge (?)',
#    'designation': 'N 4976',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229570',
#    'public': 'no',
#    'images': []},
#   'P229573': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 014 P1',
#    'collection': 'Oriental Institute, University of Chicago, Chicago, Illinois, USA',
#    'excavation_no': '3N-T0329',
#    'genre': 'School',
#    'id_text': 'P229573',
#    'language': 'Sumerian',
#    'museum_no': 'A 30214',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi 1',
#    'designation': 'A 30214',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229573'},
#   'P229576': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229576',
#    'language': 'Sumerian',
#    'museum_no': 'UM 29-13-511',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi 1',
#    'text_remarks': 'Sale of a real estate',
#    'designation': 'UM 29-13-511',
#    'electronic_publication': 'Landsberger, Civil &amp; Reiner, MSL 13, 015 U1',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229576',
#    'public': 'no',
#    'images': []},
#   'P229582': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 015 D2',
#    'collection': 'Oriental Institute, University of Chicago, Chicago, Illinois, USA',
#    'genre': 'School',
#    'id_text': 'P229582',
#    'language': 'Sumerian',
#    'museum_no': 'A 33416',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi 1',
#    'designation': 'A 33416',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229582'},
#   'P229585': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 015 M2',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229585',
#    'language': 'Sumerian',
#    'museum_no': 'UM 29-16-071',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi 1',
#    'text_remarks': 'Marriage contract; cf. N 4103',
#    'designation': 'UM 29-16-071',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229585',
#    'public': 'no',
#    'images': []},
#   'P229588': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 015 Q2',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229588',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 13637',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi 1',
#    'designation': 'CBS 13637',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229588',
#    'public': 'no',
#    'images': []},
#   'P229621': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 065 R',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229621',
#    'language': 'Sumerian',
#    'museum_no': 'N 6091',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 124',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: OB Nippur Kagal; rev: model contract',
#    'text_remarks': 'Two sales of real estates',
#    'designation': 'N 6091',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229621',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P229633': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229633',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 06560',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'OIP 011, 014',
#    'provenience': 'Nippur',
#    'publication_date': '1929',
#    'publication_history': 'MSL 13, 092 A',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: Nigga',
#    'text_remarks': 'Loss of a sealed tablet',
#    'designation': 'OIP 011, 014',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229633',
#    'public': 'no',
#    'images': []},
#   'P229642': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 093 W',
#    'collection': 'National Museum of Iraq, Baghdad, Iraq',
#    'excavation_no': '3N-T0836',
#    'genre': 'School',
#    'id_text': 'P229642',
#    'language': 'Sumerian',
#    'museum_no': 'IM 058749',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: Nigga',
#    'designation': 'IM 058749',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229642'},
#   'P229645': {'langs': '0x02000000',
#    'project': 'obmc',
#    'accession_no': 'newpenn',
#    'citation': 'Landsberger, Civil &amp; Reiner, MSL 13, 093 Z',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229645',
#    'language': 'Sumerian',
#    'museum_no': 'N 5072',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 96',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: Nigga',
#    'designation': 'N 5072',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229645'},
#   'P229649': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Chiera, Edward',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229649',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 06489',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'OIP 011, 034',
#    'provenience': 'Nippur',
#    'publication_date': '1929',
#    'publication_history': 'MSL, 13, 093 D1',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: Nigga',
#    'text_remarks': 'Loss of a sealed tablet',
#    'designation': 'OIP 011, 034',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229649',
#    'public': 'no',
#    'images': []},
#   'P229669': {'langs': '0x02000000',
#    'project': 'obmc',
#    'citation': 'MSL 13, 095, CBS 01593',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229669',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 01593',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: Nigga; rev: model contract',
#    'text_remarks': 'Sale of ...',
#    'designation': 'CBS 01593',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229669',
#    'public': 'no',
#    'images': []},
#   'P229699': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Gordon, Edmund',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229699',
#    'language': 'Sumerian',
#    'museum_no': 'N 5863',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'SP p. 37 pl. 22 WW, N 5863',
#    'provenience': 'Nippur',
#    'publication_date': '1959',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 113; Alster Proverbs coll. 1, p. 4',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: Proverb collection 1; rev: model contract',
#    'text_remarks': 'Manumissions of female slaves; TMH 11, 01, CBS 08868, SLFN 74, 3N-T0927, 513.',
#    'designation': 'SP p. 37 pl. 22 WW, N 5863',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229699',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P229702': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Gordon, Edmund',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229702',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 13866',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'SP 162 pl. 41 M, CBS 13866',
#    'provenience': 'Nippur',
#    'publication_date': '1959',
#    'publication_history': 'Alster Proverbs coll. 2, p. 40',
#    'subgenre': 'Type I Tablet',
#    'subgenre_remarks': 'Obv: Proverb collection 2; rev: model contract',
#    'text_remarks': 'Manumissions of female slaves; cf. TMH 11, 01, CBS 08868 and N 5863.',
#    'designation': 'SP 162 pl. 41 M, CBS 13866',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229702',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P229711': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Gordon, Edmund',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229711',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 13609',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'SP 168 pl. 61 EEE',
#    'provenience': 'Nippur',
#    'publication_date': '1959',
#    'publication_history': 'Alster Proverbs 042',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: Proverb collection 2; rev: model contract',
#    'text_remarks': 'Sales of real estates',
#    'designation': 'SP 168 pl. 61 EEE',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229711',
#    'public': 'no',
#    'images': []},
#   'P229719': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Nemet-Nejat, Karen R.',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229719',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 06781',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'NABU 1994/091, CBS 06781',
#    'provenience': 'uncertain',
#    'publication_date': '1994',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: metrological table or list',
#    'text_remarks': 'Barley loan',
#    'designation': 'NABU 1994/091, CBS 06781',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229719',
#    'public': 'no',
#    'images': []},
#   'P229720': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Nemet-Nejat, Karen',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229720',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 07335 + N 5955 + N 6084',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'NABU 1994/091, CBS 07335',
#    'provenience': 'Nippur',
#    'publication_date': '1994',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: metrological table or list',
#    'text_remarks': 'Sale of temple offices',
#    'designation': 'NABU 1994/091, CBS 07335',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229720',
#    'public': 'no',
#    'images': []},
#   'P229721': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Nemet-Nejat, Karen',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229721',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 07355',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'NABU 1994/091, CBS 07355',
#    'provenience': 'Nippur',
#    'publication_date': '1994',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: metrological table or list',
#    'designation': 'NABU 1994/091, CBS 07355',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229721',
#    'public': 'no',
#    'images': []},
#   'P229722': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P229722',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 19809',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: mathematical table or list',
#    'text_remarks': 'Silver loan',
#    'designation': 'CBS 19809',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229722',
#    'public': 'no',
#    'images': []},
#   'P229743': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Spada, Gabriella',
#    'collection': 'Hilprecht-Sammlung, University of Jena, Germany',
#    'genre': 'School',
#    'id_text': 'P229743',
#    'language': 'Sumerian',
#    'museum_no': 'HS 1608 + HS 2629',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'TMH 11, 06',
#    'provenience': 'Nippur',
#    'publication_date': '2018',
#    'publication_history': 'photo in UM',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: Nippur Nigga',
#    'text_remarks': 'Barley loans (cf. A 30173, CBS 10288 and N 1326)',
#    'designation': 'TMH 11, 06',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229743',
#    'trans': ['en']},
#   'P229764': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Spada, Gabriella',
#    'collection': 'Hilprecht-Sammlung, University of Jena, Germany',
#    'genre': 'School',
#    'id_text': 'P229764',
#    'language': 'Sumerian',
#    'museum_no': 'HS 1451',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'TMH 11, 08',
#    'provenience': 'Nippur',
#    'publication_date': '2018',
#    'publication_history': 'photo in UM',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ura 5',
#    'text_remarks': 'Rent of a real estate',
#    'designation': 'TMH 11, 08',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229764',
#    'trans': ['en']},
#   'P229931': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Spada, Gabriella',
#    'collection': 'Hilprecht-Sammlung, University of Jena, Germany',
#    'genre': 'School',
#    'id_text': 'P229931',
#    'language': 'Sumerian',
#    'museum_no': 'HS 1752',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'TMH 11, 10',
#    'provenience': 'Nippur',
#    'publication_date': '2018',
#    'publication_history': 'photo in UM',
#    'subgenre': 'Type I Tablet (?)',
#    'subgenre_remarks': 'Model court cases (?)',
#    'text_remarks': 'Model court cases (?)',
#    'designation': 'TMH 11, 10',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229931',
#    'trans': ['en']},
#   'P229940': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Spada, Gabriella',
#    'collection': 'Hilprecht-Sammlung, University of Jena, Germany',
#    'genre': 'School',
#    'id_text': 'P229940',
#    'language': 'Sumerian',
#    'museum_no': 'HS 1770',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'TMH 11, 05',
#    'provenience': 'Nippur',
#    'publication_date': '2018',
#    'publication_history': 'photo in UM',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: model contracts',
#    'text_remarks': 'Several silver loans',
#    'designation': 'TMH 11, 05',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229940',
#    'trans': ['en']},
#   'P229969': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Spada, Gabriella',
#    'collection': 'Hilprecht-Sammlung, University of Jena, Germany',
#    'genre': 'School',
#    'id_text': 'P229969',
#    'language': 'Sumerian',
#    'museum_no': 'HS 1808',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'primary_publication': 'TMH 11, 07',
#    'provenience': 'Nippur',
#    'publication_date': '2018',
#    'publication_history': 'photo in UM',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi',
#    'text_remarks': 'Silver loan with a female slave as a pledge; cf. TMN p. 352, Ist Ni 10108, N 4567 and UM 29-16-482.',
#    'designation': 'TMH 11, 07',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229969',
#    'trans': ['en']},
#   'P229997': {'langs': '0x02000000',
#    'project': 'obmc',
#    'author': 'Spada, Gabriella',
#    'collection': 'Hilprecht-Sammlung, University of Jena, Germany',
#    'genre': 'School',
#    'id_text': 'P229997',
#    'language': 'Sumerian',
#    'museum_no': 'HS 1851',
#    'object_type': 'prism',
#    'period': 'Old Babylonian',
#    'primary_publication': 'TMH 11, 02',
#    'provenience': 'Nippur',
#    'publication_date': '2018',
#    'publication_history': 'photo in UM',
#    'subgenre': 'Prism',
#    'subgenre_remarks': 'Model contracts',
#    'text_remarks': 'Barley loans; cf. CBS 02298',
#    'designation': 'TMH 11, 02',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P229997',
#    'trans': ['en']},
#   'P230119': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'Arkeoloji Müzeleri, Istanbul, Turkey',
#    'genre': 'School',
#    'id_text': 'P230119',
#    'language': 'Sumerian',
#    'museum_no': 'Ist Ni 05027',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'photo Lieberman Misc. 3',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: Nigga',
#    'designation': 'Ist Ni 05027',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P230119'},
#   'P230144': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P230144',
#    'language': 'Sumerian',
#    'museum_no': 'N 3815',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'uncertain',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 67',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: metrological table or list; rev: model contract',
#    'text_remarks': 'Silver loan with a pledge; silver loan',
#    'designation': 'N 3815',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P230144',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P230212': {'langs': '0x02000000',
#    'project': 'obmc',
#    'accession_no': 'newpenn',
#    'citation': 'Veldhuis EEN, 321',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P230212',
#    'language': 'Sumerian',
#    'museum_no': 'N 4990',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'publication_history': 'Unpub. ms. Lieberman, MSLF no. 266',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Ura 1',
#    'text_remarks': 'Silver loan',
#    'designation': 'N 4990',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P230212',
#    'public': 'no',
#    'images': [],
#    'trans': ['en']},
#   'P230213': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P230213',
#    'language': 'Sumerian',
#    'museum_no': 'CBS 10365',
#    'object_preservation': 'fragment',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Lu',
#    'designation': 'CBS 10365',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P230213',
#    'public': 'no',
#    'images': []},
#   'P230218': {'langs': '0x02000000',
#    'project': 'obmc',
#    'accession_no': 'newpenn',
#    'citation': 'Civil, MSL 15, 008 B',
#    'collection': 'University of Pennsylvania Museum of Archaeology and Anthropology, Philadelphia, Pennsylvania, USA',
#    'genre': 'School',
#    'id_text': 'P230218',
#    'language': 'Sumerian',
#    'museum_no': 'N 3997 + N 4918 (+) N 4915 + N 4964',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: OB Nippur Izi 1; rev: model contract',
#    'designation': 'N 3997 + N 4918 (+) N 4915 + N 4964',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P230218'},
#   'P230241': {'langs': '0x02000000',
#    'project': 'obmc',
#    'excavation_no': '3N-T0922t',
#    'genre': 'School',
#    'id_text': 'P230241',
#    'language': 'Sumerian',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: metrological table or list',
#    'designation': '3N-T0922t',
#    'material': 'gypsum: plaster',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P230241'},
#   'P230251': {'langs': '0x02000000',
#    'project': 'obmc',
#    'excavation_no': '3N-T0922h ?',
#    'genre': 'School',
#    'id_text': 'P230251',
#    'language': 'Sumerian',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre_remarks': 'Model contracts',
#    'designation': '3N-T0922h ?',
#    'material': 'gypsum: plaster',
#    'supergenre': 'LIT',
#    'xproject': 'CDLI',
#    'uri': 'http://cdli.ucla.edu/P230251'},
#   'P230260': {'langs': '0x02000000',
#    'project': 'obmc',
#    'collection': 'Oriental Institute, University of Chicago, Chicago, Illinois, USA',
#    'excavation_no': '3N-T0131',
#    'genre': 'School',
#    'id_text': 'P230260',
#    'language': 'Sumerian',
#    'museum_no': 'A 30156',
#    'object_type': 'tablet',
#    'period': 'Old Babylonian',
#    'provenience': 'Nippur',
#    'subgenre': 'Type II Tablet',
#    'subgenre_remarks': 'Obv: model contract; rev: OB Nippur Izi 1',
#    'designation': 'A 30156',
#    'supergenre': 'LIT',
# ...
#   'P230761': '<p id="P230761">obmc:P230761 = CBS 13903 + N 3197A. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P230762': '<p id="P230762">obmc:P230762 = CBS 15011. Old Babylonian Nippur (School)</p>',
#   'P230763': '<p id="P230763">obmc:P230763 = UM 29-15-374. Old Babylonian Nippur (School)</p>',
#   'P230764': '<p id="P230764">obmc:P230764 = CBS 07919. Old Babylonian Nippur (School)</p>',
#   'P230765': '<p id="P230765">obmc:P230765 = UM 29-16-482. Old Babylonian Nippur (School)</p>',
#   'P230766': '<p id="P230766">obmc:P230766 = UM 29-16-632. Old Babylonian Nippur (School)</p>',
#   'P230767': '<p id="P230767">obmc:P230767 = N 0986. Old Babylonian Nippur (School)</p>',
#   'P230768': '<p id="P230768">obmc:P230768 = N 1318. Old Babylonian Nippur (School/&gt;Type I Tablet (?))</p>',
#   'P230769': '<p id="P230769">obmc:P230769 = N 1335. Old Babylonian Nippur (School/&gt;Type I Tablet (?))</p>',
#   'P230770': '<p id="P230770">obmc:P230770 = N 1533. Old Babylonian Nippur (School)</p>',
#   'P230771': '<p id="P230771">obmc:P230771 = N 2110. Old Babylonian Nippur (School)</p>',
#   'P230772': '<p id="P230772">obmc:P230772 = N 2563. Old Babylonian Nippur (School)</p>',
#   'P230774': '<p id="P230774">obmc:P230774 = SLFN 75, 3N-T903, 101. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P230775': '<p id="P230775">obmc:P230775 = N 3653. Old Babylonian Nippur (School)</p>',
#   'P230776': '<p id="P230776">obmc:P230776 = N 4058. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P230777': '<p id="P230777">obmc:P230777 = N 4159. Old Babylonian Nippur (School)</p>',
#   'P230778': '<p id="P230778">obmc:P230778 = N 4639. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P230779': '<p id="P230779">obmc:P230779 = N 4726. Old Babylonian Nippur (School)</p>',
#   'P230780': '<p id="P230780">obmc:P230780 = N 4783. Old Babylonian Nippur (School)</p>',
#   'P230781': '<p id="P230781">obmc:P230781 = SLFN 73, 3N-T903, 116. Old Babylonian Nippur (School)</p>',
#   'P230782': '<p id="P230782">obmc:P230782 = SLFN 76, 3N-T904, 144. Old Babylonian Nippur (School/&gt;Type I Tablet (?))</p>',
#   'P230783': '<p id="P230783">obmc:P230783 = N 5281. Old Babylonian Nippur (School)</p>',
#   'P230784': '<p id="P230784">obmc:P230784 = N 5900. Old Babylonian Nippur (School)</p>',
#   'P230785': '<p id="P230785">obmc:P230785 = N 5967. Old Babylonian Nippur (School)</p>',
#   'P230786': '<p id="P230786">obmc:P230786 = CBS 04582 + Ist Ni 05059. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P230787': '<p id="P230787">obmc:P230787 = N 5884. Old Babylonian Nippur (School)</p>',
#   'P230788': '<p id="P230788">obmc:P230788 = UM 55-21-058. Old Babylonian Nippur (School/&gt;Type III Tablet (?))</p>',
#   'P230789': '<p id="P230789">obmc:P230789 = CBS 06000. Old Babylonian Nippur (School)</p>',
#   'P230790': '<p id="P230790">obmc:P230790 = SLFN 75, 3N-T906, 247. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P230791': '<p id="P230791">obmc:P230791 = N 7117. Old Babylonian Nippur (School)</p>',
#   'P230792': '<p id="P230792">obmc:P230792 = CBS 06699. Old Babylonian Nippur (School/&gt;Type II Tablet (?))</p>',
#   'P230793': '<p id="P230793">obmc:P230793 = CBS 06711. Old Babylonian Nippur (School/&gt;Type II Tablet (?))</p>',
#   'P230794': '<p id="P230794">obmc:P230794 = CBS 10311. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P230796': '<p id="P230796">obmc:P230796 = CBS 14027. Old Babylonian Nippur (School)</p>',
#   'P230797': '<p id="P230797">obmc:P230797 = UM 29-15-142. Old Babylonian Nippur (School/&gt;Type III Tablet)</p>',
#   'P230801': '<p id="P230801">obmc:P230801 = IM 057879. Old Babylonian Nippur (School/&gt;Type I (or II) Tablet)</p>',
#   'P230802': '<p id="P230802">obmc:P230802 = IM 057967. Old Babylonian Nippur (School)</p>',
#   'P230803': '<p id="P230803">obmc:P230803 = IM 058560. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P230804': '<p id="P230804">obmc:P230804 = IM 058568. Old Babylonian Nippur (School)</p>',
#   'P230805': '<p id="P230805">obmc:P230805 = IM 058583. Old Babylonian Nippur (School)</p>',
#   'P230806': '<p id="P230806">obmc:P230806 = IM 058639. Old Babylonian Nippur (School/&gt;Type I or II Tablet)</p>',
#   'P230817': '<p id="P230817">obmc:P230817 = 3N-T0914bb. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P230819': '<p id="P230819">obmc:P230819 = JAOS 120, 399. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P230975': '<p id="P230975">obmc:P230975 = N 6037. Old Babylonian Nippur (School)</p>',
#   'P230985': '<p id="P230985">obmc:P230985 = N 6100. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P231090': '<p id="P231090">obmc:P231090 = N 4668. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P231335': '<p id="P231335">obmc:P231335 = N 5381. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P231388': '<p id="P231388">obmc:P231388 = Ist Ni 05364. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P231407': '<p id="P231407">obmc:P231407 = N 5529. Old Babylonian Nippur (School)</p>',
#   'P231446': '<p id="P231446">obmc:P231446 = Ist Ni 01576. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P231447': '<p id="P231447">obmc:P231447 = Ist Ni 05371 + Ist Ni 10032. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P231448': '<p id="P231448">obmc:P231448 = TMH 11, 01. Old Babylonian Nippur (School/&gt;Prism)</p>',
#   'P231449': '<p id="P231449">obmc:P231449 = TMH 11, 04. Old Babylonian Nippur (School/&gt;Type I Tablet (micro-tablet))</p>',
#   'P231450': '<p id="P231450">obmc:P231450 = TMH 11, 03. Old Babylonian Nippur (School/&gt;Prism)</p>',
#   'P231451': '<p id="P231451">obmc:P231451 = TMH 11, 11. Old Babylonian Nippur (School)</p>',
#   'P231617': '<p id="P231617">obmc:P231617 = Proverbs 144, Ni 05098. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P231716': '<p id="P231716">obmc:P231716 = N 6981. Old Babylonian Nippur (School)</p>',
#   'P231757': '<p id="P231757">obmc:P231757 = TMN p. 331, Ist Ni 03242. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P248006': '<p id="P248006">obmc:P248006 = HMA 9-01915. Old Babylonian uncertain (School/&gt;Type I Tablet (?))</p>',
#   'P250815': '<p id="P250815">obmc:P250815 = MS 2043. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P251516': '<p id="P251516">obmc:P251516 = MS 2279. Old Babylonian uncertain (School/&gt;Type III tablet)</p>',
#   'P251517': '<p id="P251517">obmc:P251517 = MS 2280. Old Babylonian uncertain (School/&gt;Type II Tablet)</p>',
#   'P251564': '<p id="P251564">obmc:P251564 = MS 2341. Old Babylonian uncertain (School/&gt;Prism)</p>',
#   'P251568': '<p id="P251568">obmc:P251568 = MS 2348. Old Babylonian uncertain (School/&gt;Type I Tablet)</p>',
#   'P252010': '<p id="P252010">obmc:P252010 = Fs Kienast (2003), 111. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P252249': '<p id="P252249">obmc:P252249 = MS 3308. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P252260': '<p id="P252260">obmc:P252260 = MS 3319. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P252262': '<p id="P252262">obmc:P252262 = MS 3321. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P252271': '<p id="P252271">obmc:P252271 = MS 3330. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P252274': '<p id="P252274">obmc:P252274 = MS 3333. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P252280': '<p id="P252280">obmc:P252280 = MS 3339. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P252290': '<p id="P252290">obmc:P252290 = MS 3349. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P252326': '<p id="P252326">obmc:P252326 = MS 3385. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P253216': '<p id="P253216">obmc:P253216 = MS 4119. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P253576': '<p id="P253576">obmc:P253576 = MS 4423. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P254010': '<p id="P254010">obmc:P254010 = MS 4979. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P255081': '<p id="P255081">obmc:P255081 = UM 29-15-617. Old Babylonian Nippur (School/&gt;Type I or II Tablet)</p>',
#   'P256835': '<p id="P256835">obmc:P256835 = UM 29-16-291 + N 4167. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P256988': '<p id="P256988">obmc:P256988 = UM 29-16-500. Old Babylonian Nippur (School/&gt;Type II Tablet?)</p>',
#   'P266507': '<p id="P266507">obmc:P266507 = CBS 11358 + N 1960 + N 5871. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P266538': '<p id="P266538">obmc:P266538 = CBS 11399. Old Babylonian Nippur (School/&gt;Type III Tablet)</p>',
#   'P273797': '<p id="P273797">obmc:P273797 = Education in the Earliest Schools no. 056. Old Babylonian uncertain (School/&gt;Type I Tablet)</p>',
#   'P273878': '<p id="P273878">obmc:P273878 = Education in the Earliest Schools no. 178. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P273879': '<p id="P273879">obmc:P273879 = Education in the Earliest Schools no. 180. Old Babylonian uncertain (School/&gt;Type I Tablet)</p>',
#   'P276516': '<p id="P276516">obmc:P276516 = N 1369 + N 1381. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P276764': '<p id="P276764">obmc:P276764 = N 1640. Old Babylonian Nippur (School)</p>',
#   'P279804': '<p id="P279804">obmc:P279804 = N 5723. Old Babylonian Nippur (School/&gt;Type I Tablet)</p>',
#   'P283681': '<p id="P283681">obmc:P283681 = UET 5, 260. Old Babylonian Ur (School/&gt;Type III Tablet)</p>',
#   'P283684': '<p id="P283684">obmc:P283684 = UET 5, 322. Old Babylonian Ur (School/&gt;Type III Tablet)</p>',
#   'P283685': '<p id="P283685">obmc:P283685 = UET 5, 366. Old Babylonian Ur (School/&gt;Type III Tablet)</p>',
#   'P283687': '<p id="P283687">obmc:P283687 = UET 5, 388. Old Babylonian Ur (School/&gt;Type III Tablet)</p>',
#   'P283689': '<p id="P283689">obmc:P283689 = UET 5, 428. Old Babylonian Ur (School/&gt;Type III Tablet)</p>',
#   'P289409': '<p id="P289409">obmc:P289409 = CBCY 02, p. 089, NBC 08623. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P290144': '<p id="P290144">obmc:P290144 = CBCY 02, p. 072, NBC 07800a. Old Babylonian uncertain (School/&gt;Type I Tablet)</p>',
#   'P299975': '<p id="P299975">obmc:P299975 = CBCY 02, p. 089, NBC 08630. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P313251': '<p id="P313251">obmc:P313251 = ARN 135. Old Babylonian Nippur (School/&gt;Type III Tablet)</p>',
#   'P342643': '<p id="P342643">obmc:P342643 = MS 3176/5. Old Babylonian uncertain (School/&gt;Type I Tablet)</p>',
#   'P342646': '<p id="P342646">obmc:P342646 = MS 3179. Old Babylonian uncertain (School/&gt;Prism)</p>',
#   'P349178': '<p id="P349178">obmc:P349178 = AUWE 23, 183. Old Babylonian Uruk (School/&gt;Type II Tablet)</p>',
#   'P349179': '<p id="P349179">obmc:P349179 = AUWE 23, 184. Old Babylonian Uruk (School/&gt;Type II Tablet)</p>',
#   'P349180': '<p id="P349180">obmc:P349180 = AUWE 23, 185. Old Babylonian Uruk (School/&gt;Type II Tablet)</p>',
#   'P349181': '<p id="P349181">obmc:P349181 = AUWE 23, 186. Old Babylonian Uruk (School/&gt;Type II Tablet)</p>',
#   'P349182': '<p id="P349182">obmc:P349182 = AUWE 23, 187. Old Babylonian Uruk (School/&gt;Type II Tablet)</p>',
#   'P368830': '<p id="P368830">obmc:P368830 = TMN p. 341, Ist Ni 04744. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P368903': '<p id="P368903">obmc:P368903 = TMN p. 350, Ist Ni 10009. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P368906': '<p id="P368906">obmc:P368906 = TMN p. 351, Ist Ni 10062. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P368911': '<p id="P368911">obmc:P368911 = TMN p. 352, Ist Ni 10108. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P368932': '<p id="P368932">obmc:P368932 = TMN p. 355 Ist Ni 10210. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'P370464': '<p id="P370464">obmc:P370464 = CT 08, pl. 25, Bu 1891-05-09, 0558. Old Babylonian Sippar (School/&gt;Type III Tablet)</p>',
#   'P388287': '<p id="P388287">obmc:P388287 = Education in the Earliest Schools no. 053. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P388288': '<p id="P388288">obmc:P388288 = Education in the Earliest Schools no. 054. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P388303': '<p id="P388303">obmc:P388303 = Education in the Earliest Schools no. 076. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P388304': '<p id="P388304">obmc:P388304 = Education in the Earliest Schools no. 077. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P388305': '<p id="P388305">obmc:P388305 = CDLJ 2014/2. Old Babylonian Larsa (?) (School/&gt;Type III Tablet)</p>',
#   'P388376': '<p id="P388376">obmc:P388376 = Education in the Earliest Schools no. 176. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P388377': '<p id="P388377">obmc:P388377 = AION 72. Old Babylonian Larsa (?) (School/&gt;Type III Tablet)</p>',
#   'P388580': '<p id="P388580">obmc:P388580 = Education in the Earliest Schools no. 179. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P390404': '<p id="P390404">obmc:P390404 = TLB 01, 266. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'P411563': '<p id="P411563">obmc:P411563 = CUNES 52-02-045. Old Babylonian uncertain (School/&gt;Type II Tablet)</p>',
#   'P411647': '<p id="P411647">obmc:P411647 = CUNES 52-08-065. Old Babylonian uncertain (School/&gt;Prism)</p>',
#   'P411668': '<p id="P411668">obmc:P411668 = CUNES 52-10-147+149+150. Old Babylonian uncertain (School/&gt;Prism)</p>',
#   'P411669': '<p id="P411669">obmc:P411669 = CUNES 52-10-148. Old Babylonian uncertain (School/&gt;Prism)</p>',
#   'P411676': '<p id="P411676">obmc:P411676 = CUNES 52-10-155. Old Babylonian uncertain (School/&gt;Prism)</p>',
#   'P433189': '<p id="P433189">obmc:P433189 = X.3.217. Old Babylonian uncertain (School/&gt;Prism)</p>',
#   'P448857': '<p id="P448857">obmc:P448857 = Nisaba 19, 161. Old Babylonian Ur (School/&gt;Type I Tablet)</p>',
#   'P459060': '<p id="P459060">obmc:P459060 = OIC 22, 14. Old Babylonian Nippur (School/&gt;Type III Tablet)</p>',
#   'P459214': '<p id="P459214">obmc:P459214 = AOAT 297, 337. Old Babylonian Nippur (School)</p>',
#   'P459215': '<p id="P459215">obmc:P459215 = IM 058436. Old Babylonian Nippur (School/&gt;Type III Tablet)</p>',
#   'X000001': '<p id="X000001">obmc:X000001 = 3N-T0567. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'X000002': '<p id="X000002">obmc:X000002 = BM 080491. Old Babylonian Sippar (School/&gt;Type III Tablet)</p>',
#   'X000003': '<p id="X000003">obmc:X000003 = Ist Ni 05358. Old Babylonian Nippur (School/&gt;Type II Tablet)</p>',
#   'X000004': '<p id="X000004">obmc:X000004 = BM 079062. Sippar (School/&gt;Type III Tablet)</p>',
#   'X000005': '<p id="X000005">obmc:X000005 = BM 054697. Old Babylonian Sippar (School/&gt;Type I Tablet)</p>',
#   'X000006': '<p id="X000006">obmc:X000006 = Ist Ni 10200. Old Babylonian unclear (School/&gt;Prism)</p>',
#   'X000007': '<p id="X000007">obmc:X000007 = Edubba 9 29. Old Babylonian Tulul Khattab (School/&gt;Type III Tablet)</p>',
#   'X000008': '<p id="X000008">obmc:X000008 = Edubba 9 30. Old Babylonian Tulul Khattab (School/&gt;Type III Tablet)</p>',
#   'X000009': '<p id="X000009">obmc:X000009 = YBC 11121. Old Babylonian uncertain (School)</p>',
#   'X000010': '<p id="X000010">obmc:X000010 = BM 061370. Old Babylonian Sippar (School/&gt;Type III Tablet)</p>',
#   'X000011': '<p id="X000011">obmc:X000011 = ZA 101, 204-245. Old Babylonian uncertain (School/&gt;Prism)</p>',
#   'X000012': '<p id="X000012">obmc:X000012 = YBC 00263. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>',
#   'X000013': '<p id="X000013">obmc:X000013 = YBC 12074. Old Babylonian uncertain (School/&gt;Type III Tablet)</p>'}}

# %% [markdown]
# # Structure of catalogue.json
#
# A JSON file is, essentially, a Python dictionary with keys and values (in JSON-speak they are called names and values, but we will use the Python vocabulary).
#
# It turns out that `catalogue.json` has a couple of top-level keys (`type`, `project`, `source`, `license`, etc.). The key `members` is the main top-level key - this contains a new dictionary where each key is a unique text ID number (starting with P). This key, in turn contains still another dictionary with all the catalog information such as museum number, object_type, genre, etc.
#
# ```
# {'type' : 'catalogue',
#  'project': 'obmc',
#  'members' : {
#             'P200931' : {'museum_no' : 'MRAH O.0118', 'object_type' : 'tablet'},
#             'P200932' : {'museum_no' : 'MRAH O.0119', 'object_type' : 'tablet'}
#             }
# }
# ```
#
# Treating the JSON as a dictionary, we can simply select the key `members` and turn that into a DataFrame.

# %%
cat_m = cat['members']
cat_df = pd.DataFrame(cat_m)
cat_df
# Out:
#                                                                   P200931  \
# accession_no                                                          NaN
# author                                                       Limet, Henri
# citation                                                              NaN
# collection              Musées royaux d'Art et d'Histoire, Brussels, B...
# designation                                        Akkadica 117 015 O.118
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P200931
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                     MRAH O.0118
# object_preservation                                                    --
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                Akkadica 117 015 O.118
# project                                                              obmc
# provenience                                                     uncertain
# public                                                                 no
# publication_date                                                     2000
# publication_history                      Speleers, Louis, RIAA (1925) 047
# subgenre                                                   Type II Tablet
# subgenre_remarks                     Obv: model contract; rev. unreadable
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks                                                          NaN
# trans                                                                 NaN
# uri                                          http://cdli.ucla.edu/P200931
# xproject                                                             CDLI
#
#                                                                   P200932  \
# accession_no                                                          NaN
# author                                                       Limet, Henri
# citation                                                              NaN
# collection              Musées royaux d'Art et d'Histoire, Brussels, B...
# designation                                        Akkadica 117 015 O.119
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P200932
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                     MRAH O.0119
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                Akkadica 117 015 O.119
# project                                                              obmc
# provenience                                                     uncertain
# public                                                                 no
# publication_date                                                     2000
# publication_history                      Speleers, Louis, RIAA (1925) 049
# subgenre                                                  Type III Tablet
# subgenre_remarks                                           Model contract
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks            Manumission of a male slave; cf. Akkadica 117 ...
# trans                                                                [en]
# uri                                          http://cdli.ucla.edu/P200932
# xproject                                                             CDLI
#
#                                                                   P200933  \
# accession_no                                                          NaN
# author                                                       Limet, Henri
# citation                                                              NaN
# collection              Musées royaux d'Art et d'Histoire, Brussels, B...
# designation                                        Akkadica 117 016 O.120
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P200933
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                      MRAH O.120
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                Akkadica 117 016 O.120
# project                                                              obmc
# provenience                                                     uncertain
# public                                                                 no
# publication_date                                                     2000
# publication_history                             Speleers, Louis, RIAA 045
# subgenre                                                  Type III Tablet
# subgenre_remarks                                           Model contract
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks            Manumission of a male slave; cf. Akkadica 117 ...
# trans                                                                 NaN
# uri                                          http://cdli.ucla.edu/P200933
# xproject                                                             CDLI
#
#                                                                   P227953  \
# accession_no                                                          NaN
# author                                                     Chiera, Edward
# citation                                                              NaN
# collection              University of Pennsylvania Museum of Archaeolo...
# designation                                      OIP 011, 105 + 109 + 148
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P227953
# images                                                                NaN
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                               CBS 04803 + CBS 06591 + CBS 05962
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                              OIP 011, 105 + 109 + 148
# project                                                              obmc
# provenience                                                        Nippur
# public                                                                NaN
# publication_date                                                     1929
# publication_history     MSL 12, 029 L + 031 Y'; MSL 05, 169 (on OIP 01...
# subgenre                                                   Type II Tablet
# subgenre_remarks                   Obv: model contract; rev: OB Nippur Lu
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks                                              Sale of a field
# trans                                                                 NaN
# uri                                          http://cdli.ucla.edu/P227953
# xproject                                                             CDLI
#
#                                                                   P227955  \
# accession_no                                                          NaN
# author                                                     Chiera, Edward
# citation                                                              NaN
# collection              University of Pennsylvania Museum of Archaeolo...
# designation                                                  OIP 011, 030
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P227955
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                       CBS 04805
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                          OIP 011, 030
# project                                                              obmc
# provenience                                                        Nippur
# public                                                                 no
# publication_date                                                     1929
# publication_history                                         MSL 13, 092 B
# subgenre                                                   Type II Tablet
# subgenre_remarks                          Obv: model contract; rev: Nigga
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks                                                 Silver loans
# trans                                                                 NaN
# uri                                          http://cdli.ucla.edu/P227955
# xproject                                                             CDLI
#
#                                                                   P227962  \
# accession_no                                                          NaN
# author                                                                NaN
# citation                                                              NaN
# collection              University of Pennsylvania Museum of Archaeolo...
# designation                                         CBS 04813 + CBS 06853
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P227962
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                           CBS 04813 + CBS 06853
# object_preservation                                              fragment
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                                   NaN
# project                                                              obmc
# provenience                                                     uncertain
# public                                                                 no
# publication_date                                                      NaN
# publication_history                                                   NaN
# subgenre                                              Type I or II Tablet
# subgenre_remarks                                          Model contracts
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks                                                 Barley loans
# trans                                                                [en]
# uri                                          http://cdli.ucla.edu/P227962
# xproject                                                             CDLI
#
#                                                                   P227972  \
# accession_no                                                          NaN
# author                                                     Chiera, Edward
# citation                                                              NaN
# collection              University of Pennsylvania Museum of Archaeolo...
# designation                      OIP 011, p. 014, CBS 04826 (unpub. dup.)
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P227972
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                       CBS 04826
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication              OIP 011, p. 014, CBS 04826 (unpub. dup.)
# project                                                              obmc
# provenience                                                        Nippur
# public                                                                 no
# publication_date                                                     1929
# publication_history                                                   NaN
# subgenre                                                   Type II Tablet
# subgenre_remarks                Obv: model contract; rev: OB Nippur Ura 4
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks                                              Rent of a field
# trans                                                                 NaN
# uri                                          http://cdli.ucla.edu/P227972
# xproject                                                             CDLI
#
#                                                                   P227988  \
# accession_no                                                          NaN
# author                                                     Chiera, Edward
# citation                                                              NaN
# collection              University of Pennsylvania Museum of Archaeolo...
# designation                                                  OIP 011, 096
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P227988
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                       CBS 04846
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                          OIP 011, 096
# project                                                              obmc
# provenience                                                        Nippur
# public                                                                 no
# publication_date                                                     1929
# publication_history                                      MSL 7, 179 (V20)
# subgenre                                                   Type II Tablet
# subgenre_remarks                Obv: model contract; rev: OB Nippur Ura 2
# supergenre                                                            LIT
# surface_preservation                                                   --
# text_remarks                                             Two barley loans
# trans                                                                [en]
# uri                                          http://cdli.ucla.edu/P227988
# xproject                                                             CDLI
#
#                                                                   P228140  \
# accession_no                                                          NaN
# author                                                                NaN
# citation                                                              NaN
# collection              University of Pennsylvania Museum of Archaeolo...
# designation                                                        N 2469
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P228140
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                          N 2469
# object_preservation                                              fragment
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                                   NaN
# project                                                              obmc
# provenience                                                        Nippur
# public                                                                 no
# publication_date                                                      NaN
# publication_history                                                   NaN
# subgenre                                                              NaN
# subgenre_remarks                                           Model contract
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks            Manumission of a female slave; cf. TMH 11, 01,...
# trans                                                                [en]
# uri                                          http://cdli.ucla.edu/P228140
# xproject                                                             CDLI
#
#                                                                   P228267  \
# accession_no                                                          NaN
# author                                                                NaN
# citation                                                              NaN
# collection              University of Pennsylvania Museum of Archaeolo...
# designation                                                        N 4541
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           P228267
# images                                                                 []
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                          N 4541
# object_preservation                                              fragment
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                                   NaN
# project                                                              obmc
# provenience                                                        Nippur
# public                                                                 no
# publication_date                                                      NaN
# publication_history                                                   NaN
# subgenre                                                   Type II Tablet
# subgenre_remarks                  Obv: model contract; rev: not preserved
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks                                                          NaN
# trans                                                                 NaN
# uri                                          http://cdli.ucla.edu/P228267
# xproject                                                             CDLI
#
#                                               ...                          \
# accession_no                                  ...
# author                                        ...
# citation                                      ...
# collection                                    ...
# designation                                   ...
# electronic_publication                        ...
# excavation_no                                 ...
# findspot_square                               ...
# genre                                         ...
# id_text                                       ...
# images                                        ...
# langs                                         ...
# language                                      ...
# material                                      ...
# museum_no                                     ...
# object_preservation                           ...
# object_remarks                                ...
# object_type                                   ...
# period                                        ...
# primary_publication                           ...
# project                                       ...
# provenience                                   ...
# public                                        ...
# publication_date                              ...
# publication_history                           ...
# subgenre                                      ...
# subgenre_remarks                              ...
# supergenre                                    ...
# surface_preservation                          ...
# text_remarks                                  ...
# trans                                         ...
# uri                                           ...
# xproject                                      ...
#
#                                                                   X000004  \
# accession_no                                                          NaN
# author                                                                NaN
# citation                                               Veldhuis 2014: 193
# collection                                     British Museum, London, UK
# designation                                                     BM 079062
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           X000004
# images                                                                NaN
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                       BM 079062
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                                NaN
# primary_publication                                                   NaN
# project                                                              obmc
# provenience                                                        Sippar
# public                                                                NaN
# publication_date                                                      NaN
# publication_history                                                   NaN
# subgenre                                                  Type III Tablet
# subgenre_remarks                                           Model contract
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks            List of the symbolic gestures related to the m...
# trans                                                                 NaN
# uri                                                                   NaN
# xproject                                                              NaN
#
#                                            X000005  \
# accession_no                                   NaN
# author                                         NaN
# citation                                       NaN
# collection              British Museum, London, UK
# designation                              BM 054697
# electronic_publication                         NaN
# excavation_no                                  NaN
# findspot_square                                NaN
# genre                                       School
# id_text                                    X000005
# images                                         NaN
# langs                                   0x02000000
# language                                  Sumerian
# material                                       NaN
# museum_no                                BM 054697
# object_preservation                            NaN
# object_remarks                                 NaN
# object_type                                    NaN
# period                              Old Babylonian
# primary_publication                            NaN
# project                                       obmc
# provenience                                 Sippar
# public                                         NaN
# publication_date                               NaN
# publication_history                            NaN
# subgenre                             Type I Tablet
# subgenre_remarks                   Model contracts
# supergenre                                     LIT
# surface_preservation                           NaN
# text_remarks                                   NaN
# trans                                          NaN
# uri                                            NaN
# xproject                                       NaN
#
#                                                      X000006  \
# accession_no                                             NaN
# author                                                   NaN
# citation                                                 NaN
# collection              Arkeoloji Müzeleri, Istanbul, Turkey
# designation                                     Ist Ni 10200
# electronic_publication                                   NaN
# excavation_no                                            NaN
# findspot_square                                          NaN
# genre                                                 School
# id_text                                              X000006
# images                                                   NaN
# langs                                             0x02000000
# language                                            Sumerian
# material                                                 NaN
# museum_no                                       Ist Ni 10200
# object_preservation                                 fragment
# object_remarks                                           NaN
# object_type                                            prism
# period                                        Old Babylonian
# primary_publication                                      NaN
# project                                                 obmc
# provenience                                          unclear
# public                                                   NaN
# publication_date                                         NaN
# publication_history                                      NaN
# subgenre                                               Prism
# subgenre_remarks                             Model contracts
# supergenre                                               LIT
# surface_preservation                                     NaN
# text_remarks                                    Barley loans
# trans                                                    NaN
# uri                                                      NaN
# xproject                                                 NaN
#
#                                                                   X000007  \
# accession_no                                                          NaN
# author                                              Isma'el, Khalid Salim
# citation                                                              NaN
# collection                               National Museum of Iraq, Baghdad
# designation                                                   Edubba 9 29
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           X000007
# images                                                                NaN
# langs                                                                 NaN
# language                                                              NaN
# material                                                              NaN
# museum_no                                                       IM 092207
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                           Edubba 9 29
# project                                                              obmc
# provenience                                                 Tulul Khattab
# public                                                                NaN
# publication_date                                                     2007
# publication_history                                                   NaN
# subgenre                                                  Type III Tablet
# subgenre_remarks                                           Model contract
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks            Manumission of a male slave; cf. Akkadica 117 ...
# trans                                                                [en]
# uri                                                                   NaN
# xproject                                                              NaN
#
#                                                  X000008  \
# accession_no                                         NaN
# author                             Isma'el, Khalid Salim
# citation                                             NaN
# collection              National Museum of Iraq, Baghdad
# designation                                  Edubba 9 30
# electronic_publication                               NaN
# excavation_no                                        NaN
# findspot_square                                      NaN
# genre                                             School
# id_text                                          X000008
# images                                               NaN
# langs                                         0x02000000
# language                                        Sumerian
# material                                             NaN
# museum_no                                      IM 090572
# object_preservation                                  NaN
# object_remarks                                       NaN
# object_type                                       tablet
# period                                    Old Babylonian
# primary_publication                          Edubba 9 30
# project                                             obmc
# provenience                                Tulul Khattab
# public                                               NaN
# publication_date                                    2007
# publication_history                                  NaN
# subgenre                                 Type III Tablet
# subgenre_remarks                          Model contract
# supergenre                                           LIT
# surface_preservation                                 NaN
# text_remarks                        Sale of a male slave
# trans                                               [en]
# uri                                                  NaN
# xproject                                             NaN
#
#                                                         X000009  \
# accession_no                                                NaN
# author                                        Bodine, Walter R.
# citation                                                    NaN
# collection                Yale Babylonian Collection, New Haven
# designation                                           YBC 11121
# electronic_publication                                      NaN
# excavation_no                                               NaN
# findspot_square                                             NaN
# genre                                                    School
# id_text                                                 X000009
# images                                                      NaN
# langs                                                0x02000000
# language                                               Sumerian
# material                                                    NaN
# museum_no                                             YBC 11121
# object_preservation                                    fragment
# object_remarks                                              NaN
# object_type                                            cylinder
# period                                           Old Babylonian
# primary_publication                                   YBC 11121
# project                                                    obmc
# provenience                                           uncertain
# public                                                      NaN
# publication_date                                           2015
# publication_history                                         NaN
# subgenre                                                    NaN
# subgenre_remarks                                Model contracts
# supergenre                                                  LIT
# surface_preservation                                        NaN
# text_remarks            Several sales of real estates; adoption
# trans                                                       NaN
# uri                                                         NaN
# xproject                                                    NaN
#
#                                            X000010  \
# accession_no                                   NaN
# author                                         NaN
# citation                                       NaN
# collection              British Museum, London, UK
# designation                              BM 061370
# electronic_publication                         NaN
# excavation_no                                  NaN
# findspot_square                                NaN
# genre                                       School
# id_text                                    X000010
# images                                         NaN
# langs                                   0x02000000
# language                                  Sumerian
# material                                       NaN
# museum_no                                BM 061370
# object_preservation                            NaN
# object_remarks                                 NaN
# object_type                                 tablet
# period                              Old Babylonian
# primary_publication                            NaN
# project                                       obmc
# provenience                                 Sippar
# public                                         NaN
# publication_date                               NaN
# publication_history                            NaN
# subgenre                           Type III Tablet
# subgenre_remarks                    Model contract
# supergenre                                     LIT
# surface_preservation                           NaN
# text_remarks                                   NaN
# trans                                          NaN
# uri                                            NaN
# xproject                                       NaN
#
#                                                                   X000011  \
# accession_no                                                          NaN
# author                                                   Spada, Gabriella
# citation                                                              NaN
# collection                                  private: anonymous, unlocated
# designation                                               ZA 101, 204-245
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           X000011
# images                                                                NaN
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                             NaN
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                         prism
# period                                                     Old Babylonian
# primary_publication                                       ZA 101, 204-245
# project                                                              obmc
# provenience                                                     uncertain
# public                                                                NaN
# publication_date                                                     2011
# publication_history                                                   NaN
# subgenre                                                            Prism
# subgenre_remarks                        Model contracts; model court case
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks            Several loan contracts (barley, sesame, bricks...
# trans                                                                [en]
# uri                                                                   NaN
# xproject                                                              NaN
#
#                                                       X000012  \
# accession_no                                              NaN
# author                                      Bodine, Walter R.
# citation                                                  NaN
# collection              Yale Babylonian Collection, New Haven
# designation                                         YBC 00263
# electronic_publication                                    NaN
# excavation_no                                             NaN
# findspot_square                                           NaN
# genre                                                  School
# id_text                                               X000012
# images                                                    NaN
# langs                                              0x02000000
# language                                             Sumerian
# material                                                  NaN
# museum_no                                           YBC 00263
# object_preservation                                       NaN
# object_remarks                                            NaN
# object_type                                            tablet
# period                                         Old Babylonian
# primary_publication                                 YBC 00263
# project                                                  obmc
# provenience                                         uncertain
# public                                                    NaN
# publication_date                                         2015
# publication_history                                       NaN
# subgenre                                      Type III Tablet
# subgenre_remarks                               Model contract
# supergenre                                                LIT
# surface_preservation                                      NaN
# text_remarks                                      Silver loan
# trans                                                    [en]
# uri                                                       NaN
# xproject                                                  NaN
#
#                                                                   X000013
# accession_no                                                          NaN
# author                                                  Bodine, Walter R.
# citation                                                              NaN
# collection                          Yale Babylonian Collection, New Haven
# designation                                                     YBC 12074
# electronic_publication                                                NaN
# excavation_no                                                         NaN
# findspot_square                                                       NaN
# genre                                                              School
# id_text                                                           X000013
# images                                                                NaN
# langs                                                          0x02000000
# language                                                         Sumerian
# material                                                              NaN
# museum_no                                                       YBC 12074
# object_preservation                                                   NaN
# object_remarks                                                        NaN
# object_type                                                        tablet
# period                                                     Old Babylonian
# primary_publication                                             YBC 12074
# project                                                              obmc
# provenience                                                     uncertain
# public                                                                NaN
# publication_date                                                     2015
# publication_history                                                   NaN
# subgenre                                                  Type III Tablet
# subgenre_remarks                                         Model court case
# supergenre                                                            LIT
# surface_preservation                                                  NaN
# text_remarks            Public announcement of a lost seal (cf. NBC 07...
# trans                                                                [en]
# uri                                                                   NaN
# xproject                                                              NaN
#
# [33 rows x 345 columns]

# %% [markdown]
# # Improve
#
# This is a little odd: each text ID is a column (we expected a row). All the NaNs are uninteresting and we have far too many fileds.

# %%
cat_df = cat_df.T.fillna('')
cat_df = cat_df[['designation', 'period', 'provenience',
        'museum_no', 'id_text']]
cat_df[:10]
# Out:
#                                       designation          period provenience  \
# P200931                    Akkadica 117 015 O.118  Old Babylonian   uncertain
# P200932                    Akkadica 117 015 O.119  Old Babylonian   uncertain
# P200933                    Akkadica 117 016 O.120  Old Babylonian   uncertain
# P227953                  OIP 011, 105 + 109 + 148  Old Babylonian      Nippur
# P227955                              OIP 011, 030  Old Babylonian      Nippur
# P227962                     CBS 04813 + CBS 06853  Old Babylonian   uncertain
# P227972  OIP 011, p. 014, CBS 04826 (unpub. dup.)  Old Babylonian      Nippur
# P227988                              OIP 011, 096  Old Babylonian      Nippur
# P228140                                    N 2469  Old Babylonian      Nippur
# P228267                                    N 4541  Old Babylonian      Nippur
#
#                                  museum_no  id_text
# P200931                        MRAH O.0118  P200931
# P200932                        MRAH O.0119  P200932
# P200933                         MRAH O.120  P200933
# P227953  CBS 04803 + CBS 06591 + CBS 05962  P227953
# P227955                          CBS 04805  P227955
# P227962              CBS 04813 + CBS 06853  P227962
# P227972                          CBS 04826  P227972
# P227988                          CBS 04846  P227988
# P228140                             N 2469  P228140
# P228267                             N 4541  P228267

# %% [markdown]
# # Save or Pickle for later use
# Save to a `csv` file with the `Pandas` command `to_csv()`. Use `encoding = "utf8"` if you want to read the file in another Python or R project. Use `encoding = 'utf16'` if you plan to open the file in Excel.
#
# If the file gets only used in Python projects, you may also pickle the file and you can essentially continue where you left off.

# %%
filename = 'obmc_cat.csv'
p_filename = "obmc_cat.p"
with open(filename, 'w', encoding='utf-8') as w:
    cat_df.to_csv(w, index=False)

with open(p_filename, 'wb') as p:
    pickle.dump(cat_df, p)

# %% [markdown]
# # Open your Pickle file
#
# In theory you can open your pickle file with the command `load()` - and that is probably going to work right now. However, it is often better to load the file directly into Pandas with the `read_pickle()` command (you can also pickle your dataframe with `pd.to_pickle()`).

# %%
df = pd.read_pickle("obmc_cat.p")
df
# Out:
#                                        designation          period  \
# P200931                     Akkadica 117 015 O.118  Old Babylonian
# P200932                     Akkadica 117 015 O.119  Old Babylonian
# P200933                     Akkadica 117 016 O.120  Old Babylonian
# P227953                   OIP 011, 105 + 109 + 148  Old Babylonian
# P227955                               OIP 011, 030  Old Babylonian
# P227962                      CBS 04813 + CBS 06853  Old Babylonian
# P227972   OIP 011, p. 014, CBS 04826 (unpub. dup.)  Old Babylonian
# P227988                               OIP 011, 096  Old Babylonian
# P228140                                     N 2469  Old Babylonian
# P228267                                     N 4541  Old Babylonian
# P228489                                     N 5544  Old Babylonian
# P228766                               BPOA 09, 257  Old Babylonian
# P228782                               UM 29-16-583  Old Babylonian
# P228991                              PBS 11/1, 040  Old Babylonian
# P229038                                 TMH 11, 09  Old Babylonian
# P229160                                  CBS 05873  Old Babylonian
# P229166                         EEN 061, CBS 06098  Old Babylonian
# P229216                                  CBS 06542  Old Babylonian
# P229278                                     N 5350  Old Babylonian
# P229318                               OIP 011, 249  Old Babylonian
# P229326                               OIP 011, 225  Old Babylonian
# P229365                                    A 33510  Old Babylonian
# P229384                               Ist Ni 03949  Old Babylonian
# P229387                                  CBS 15210  Old Babylonian
# P229411                                     N 5248  Old Babylonian
# P229414                                  CBS 15225  Old Babylonian
# P229428                               Ist Ni 03775  Old Babylonian
# P229443                                PBS 05, 128  Old Babylonian
# P229564                                    A 30173  Old Babylonian
# P229567             N 6041 + N 6049 + UM 29-16-195  Old Babylonian
# ...                                            ...             ...
# P388303  Education in the Earliest Schools no. 076  Old Babylonian
# P388304  Education in the Earliest Schools no. 077  Old Babylonian
# P388305                                CDLJ 2014/2  Old Babylonian
# P388376  Education in the Earliest Schools no. 176  Old Babylonian
# P388377                                    AION 72  Old Babylonian
# P388580  Education in the Earliest Schools no. 179  Old Babylonian
# P390404                                TLB 01, 266  Old Babylonian
# P411563                            CUNES 52-02-045  Old Babylonian
# P411647                            CUNES 52-08-065  Old Babylonian
# P411668                    CUNES 52-10-147+149+150  Old Babylonian
# P411669                            CUNES 52-10-148  Old Babylonian
# P411676                            CUNES 52-10-155  Old Babylonian
# P433189                                    X.3.217  Old Babylonian
# P448857                             Nisaba 19, 161  Old Babylonian
# P459060                                 OIC 22, 14  Old Babylonian
# P459214                              AOAT 297, 337  Old Babylonian
# P459215                                  IM 058436  Old Babylonian
# X000001                                   3N-T0567  Old Babylonian
# X000002                                  BM 080491  Old Babylonian
# X000003                               Ist Ni 05358  Old Babylonian
# X000004                                  BM 079062
# X000005                                  BM 054697  Old Babylonian
# X000006                               Ist Ni 10200  Old Babylonian
# X000007                                Edubba 9 29  Old Babylonian
# X000008                                Edubba 9 30  Old Babylonian
# X000009                                  YBC 11121  Old Babylonian
# X000010                                  BM 061370  Old Babylonian
# X000011                            ZA 101, 204-245  Old Babylonian
# X000012                                  YBC 00263  Old Babylonian
# X000013                                  YBC 12074  Old Babylonian
#
#            provenience                          museum_no  id_text
# P200931      uncertain                        MRAH O.0118  P200931
# P200932      uncertain                        MRAH O.0119  P200932
# P200933      uncertain                         MRAH O.120  P200933
# P227953         Nippur  CBS 04803 + CBS 06591 + CBS 05962  P227953
# P227955         Nippur                          CBS 04805  P227955
# P227962      uncertain              CBS 04813 + CBS 06853  P227962
# P227972         Nippur                          CBS 04826  P227972
# P227988         Nippur                          CBS 04846  P227988
# P228140         Nippur                             N 2469  P228140
# P228267         Nippur                             N 4541  P228267
# P228489         Nippur                             N 5544  P228489
# P228766         Nippur                       UM 29-16-541  P228766
# P228782         Nippur                       UM 29-16-583  P228782
# P228991         Nippur                 CBS 05912 + N 4966  P228991
# P229038         Nippur                  HS 1607 + HS 2946  P229038
# P229160      uncertain                          CBS 05873  P229160
# P229166         Nippur        CBS 06098 + N 3960 + N 5128  P229166
# P229216         Nippur                          CBS 06542  P229216
# P229278         Nippur                             N 5350  P229278
# P229318         Nippur                          CBS 06527  P229318
# P229326         Nippur                          CBS 06530  P229326
# P229365         Nippur                            A 33510  P229365
# P229384         Nippur                       Ist Ni 03949  P229384
# P229387         Nippur                          CBS 15210  P229387
# P229411         Nippur                             N 5248  P229411
# P229414         Nippur                          CBS 15225  P229414
# P229428         Nippur                       Ist Ni 03775  P229428
# P229443         Nippur                          CBS 14006  P229443
# P229564         Nippur                            A 30173  P229564
# P229567         Nippur     N 6041 + N 6049 + UM 29-16-195  P229567
# ...                ...                                ...      ...
# P388303      uncertain                         SC 3, 023a  P388303
# P388304      uncertain                         SC 3, 023b  P388304
# P388305      Larsa (?)                         SC 3, 024a  P388305
# P388376      uncertain                         SC 3, 024e  P388376
# P388377      Larsa (?)                         SC 3, 024c  P388377
# P388580      uncertain                    PARS 12/01, 141  P388580
# P390404      uncertain                            LB 1954  P390404
# P411563      uncertain                    CUNES 52-02-045  P411563
# P411647      uncertain                    CUNES 52-08-065  P411647
# P411668      uncertain            CUNES 52-10-147+149+150  P411668
# P411669      uncertain                    CUNES 52-10-148  P411669
# P411676      uncertain                    CUNES 52-10-155  P411676
# P433189      uncertain                            X.3.217  P433189
# P448857             Ur                          IM 090430  P448857
# P459060         Nippur                                     P459060
# P459214         Nippur                            A 33446  P459214
# P459215         Nippur                          IM 058436  P459215
# X000001         Nippur                                     X000001
# X000002         Sippar                          BM 080491  X000002
# X000003         Nippur                       Ist Ni 05358  X000003
# X000004         Sippar                          BM 079062  X000004
# X000005         Sippar                          BM 054697  X000005
# X000006        unclear                       Ist Ni 10200  X000006
# X000007  Tulul Khattab                          IM 092207  X000007
# X000008  Tulul Khattab                          IM 090572  X000008
# X000009      uncertain                          YBC 11121  X000009
# X000010         Sippar                          BM 061370  X000010
# X000011      uncertain                                     X000011
# X000012      uncertain                          YBC 00263  X000012
# X000013      uncertain                          YBC 12074  X000013
#
# [345 rows x 5 columns]

# %% [markdown]
# # More Complex JSON
# The `catalogue.json` that we parsed above has a fairly simple structure. Text editions in [ORACC](http://oracc.org) JSON are much more complex because they preserve the inner structure of the document, divided into:
#     - obverse
#     - reverse
#     - column 1, column 2, etc.
#     - lines
#
# It is impossible to predict how deep the structure is: some texts have columns (tablet > side > column > line) others do not (tablet > side > line). Let's look at a simple example.
#
# We still have the ZipFile object `z`.

# %%
P = "obmc/corpusjson/P230754.json"
String = z.read(P).decode("utf8")
P230754 = json.loads(String)
P230754
# Out:
# {'type': 'cdl',
#  'project': 'obmc',
#  'source': 'http://oracc.org/obmc',
#  'license': 'This data is released under the CC0 license',
#  'license-url': 'https://creativecommons.org/publicdomain/zero/1.0/',
#  'more-info': 'http://oracc.org/doc/opendata/',
#  'UTC-timestamp': '2019-02-05T21:57:50',
#  'textid': 'P230754',
#  'cdl': [{'node': 'c',
#    'type': 'text',
#    'id': 'P230754.U0',
#    'cdl': [{'node': 'd',
#      'subtype': 'tablet',
#      'type': 'tablet',
#      'ref': 'P230754.x59.1',
#      'label': 'x59'},
#     {'node': 'd', 'type': 'surface', 'ref': ''},
#     {'node': 'd',
#      'subtype': "column 1'",
#      'type': 'column',
#      'ref': 'P230754.i_.2',
#      'n': '1',
#      'label': "i'"},
#     {'node': 'c',
#      'type': 'discourse',
#      'subtype': 'body',
#      'id': 'P230754.U1',
#      'cdl': [{'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'id': 'P230754.U2',
#        'label': "i' 1' - i' 4'",
#        'cdl': [{'node': 'd',
#          'type': 'line-start',
#          'ref': 'P230754.3',
#          'n': "1'",
#          'label': "i' 1'"},
#         {'node': 'l',
#          'frag': '{iti}⸢šeg₁₂⸣-[a-ka]',
#          'id': 'P230754.l00b16',
#          'ref': 'P230754.3.1',
#          'inst': 'Šega[1]MN',
#          'sig': "@obmc%sux:{iti}šeg₁₂-a-ka=Šega[1//1]MN'MN$Šega,ak.a/{iti}šeg₁₂-a#~,ak.a",
#          'f': {'lang': 'sux',
#           'form': '{iti}šeg₁₂-a-ka',
#           'gdl': [{'det': 'semantic',
#             'pos': 'pre',
#             'seq': [{'v': 'iti', 'id': 'P230754.3.1.0'}]},
#            {'v': 'šeg₁₂',
#             'id': 'P230754.3.1.1',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'a',
#             'id': 'P230754.3.1.2',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'ka',
#             'id': 'P230754.3.1.3',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P230754.3.1.2'}],
#           'cf': 'Šega',
#           'gw': '1',
#           'sense': '1',
#           'norm0': 'Šega,ak.a',
#           'pos': 'MN',
#           'epos': 'MN',
#           'base': '{iti}šeg₁₂-a',
#           'morph': '~,ak.a'}},
#         {'node': 'd',
#          'type': 'line-start',
#          'ref': 'P230754.4',
#          'n': "2'",
#          'label': "i' 2'"},
#         {'node': 'l',
#          'frag': 'kug-bi',
#          'id': 'P230754.l00b17',
#          'ref': 'P230754.4.1',
#          'inst': 'kug[metal, silver]N',
#          'exosig': "@obmc%sux:kug-bi=kug[metal//metal, silver]N'N$kug,bi/kug#~,bi",
#          'exoprj': 'epsd2',
#          'exolng': 'sux',
#          'f': {'lang': 'sux',
#           'form': 'kug-bi',
#           'delim': '',
#           'gdl': [{'v': 'kug', 'id': 'P230754.4.1.0', 'delim': '-'},
#            {'v': 'bi', 'id': 'P230754.4.1.1'}],
#           'cf': 'kug',
#           'gw': 'metal',
#           'sense': 'metal, silver',
#           'norm0': 'kug,bi',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'kug',
#           'morph': '~,bi'}},
#         {'node': 'l',
#          'frag': '⸢i₃⸣-[la₂-e]',
#          'id': 'P230754.l00b18',
#          'ref': 'P230754.4.2',
#          'inst': 'la[to weigh, weigh (out), pay]V/t',
#          'sig': "@obmc%sux:i₃-la₂-e=la[hang//to weigh, weigh (out), pay]V/t'V/t$V:la;e/la₂#V:~;e",
#          'f': {'lang': 'sux',
#           'form': 'i₃-la₂-e',
#           'gdl': [{'v': 'i₃',
#             'id': 'P230754.4.2.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'la₂',
#             'id': 'P230754.4.2.1',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'e',
#             'id': 'P230754.4.2.2',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P230754.4.2.1'}],
#           'cf': 'la',
#           'gw': 'hang',
#           'sense': 'to weigh, weigh (out), pay',
#           'norm0': 'V:la;e',
#           'pos': 'V/t',
#           'epos': 'V/t',
#           'base': 'la₂',
#           'morph': 'V:~;e'}},
#         {'node': 'd',
#          'type': 'line-start',
#          'ref': 'P230754.5',
#          'n': "3'",
#          'label': "i' 3'"},
#         {'node': 'l',
#          'frag': '⸢tukum⸣-[bi]',
#          'id': 'P230754.l00b19',
#          'ref': 'P230754.5.1',
#          'inst': 'tukumbi[if]CNJ',
#          'sig': "@obmc%sux:tukum-bi=tukumbi[if//if]CNJ'CNJ$tukumbi/tukum-bi#~",
#          'f': {'lang': 'sux',
#           'form': 'tukum-bi',
#           'gdl': [{'v': 'tukum',
#             'id': 'P230754.5.1.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'bi',
#             'id': 'P230754.5.1.1',
#             'breakStart': '1',
#             'o': ']',
#             'break': 'missing',
#             'breakEnd': 'P230754.5.1.1'}],
#           'cf': 'tukumbi',
#           'gw': 'if',
#           'sense': 'if',
#           'norm0': 'tukumbi',
#           'pos': 'CNJ',
#           'epos': 'CNJ',
#           'base': 'tukum-bi',
#           'morph': '~'}},
#         {'node': 'd',
#          'type': 'line-start',
#          'ref': 'P230754.6',
#          'n': "4'",
#          'label': "i' 4'"},
#         {'node': 'l',
#          'frag': '{[iti]}⸢šeg₁₂-a-ka⸣',
#          'id': 'P230754.l00b1a',
#          'ref': 'P230754.6.1',
#          'inst': 'Šega[1]MN',
#          'sig': "@obmc%sux:{iti}šeg₁₂-a-ka=Šega[1//1]MN'MN$Šega,ak.a/{iti}šeg₁₂-a#~,ak.a",
#          'f': {'lang': 'sux',
#           'form': '{iti}šeg₁₂-a-ka',
#           'gdl': [{'det': 'semantic',
#             'pos': 'pre',
#             'seq': [{'v': 'iti',
#               'id': 'P230754.6.1.0',
#               'breakStart': '1',
#               'o': ']',
#               'break': 'missing',
#               'breakEnd': 'P230754.6.1.0'}]},
#            {'v': 'šeg₁₂',
#             'id': 'P230754.6.1.1',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-'},
#            {'v': 'a', 'id': 'P230754.6.1.2', 'break': 'damaged', 'delim': '-'},
#            {'v': 'ka', 'id': 'P230754.6.1.3', 'break': 'damaged', 'hc': '1'}],
#           'cf': 'Šega',
#           'gw': '1',
#           'sense': '1',
#           'norm0': 'Šega,ak.a',
#           'pos': 'MN',
#           'epos': 'MN',
#           'base': '{iti}šeg₁₂-a',
#           'morph': '~,ak.a'}},
#         {'node': 'd',
#          'type': 'nonx',
#          'ref': 'P230754.7',
#          'strict': '1',
#          'extent': 'rest',
#          'scope': 'column',
#          'state': 'missing'}]}]}]}]}

# %% [markdown]
# The JSON is structured around `cdl` nodes. A `cdl` node is a list that may contain `c` (Chunk), `d` (Discontinuity), and `l` (Lemma) nodes, and/or a new `cdl` node. The hierarchy of `cdl` nodes represents the textual hierarchy. We therefore dig into the JSON until we find no more new `cdl` nodes.

# %%
def parsejson(text):
    for JSONobject in text["cdl"]:
        if "cdl" in JSONobject: 
            parsejson(JSONobject)
        if "f" in JSONobject:
            lemm = JSONobject["f"]
            lemm["id_text"] = id_text
            lemm_l.append(lemm)
    return

# %%
id_text = "P230754"
lemm_l = []
parsejson(P230754)

# %%
lemm_l
# Out:
# [{'lang': 'sux',
#   'form': '{iti}šeg₁₂-a-ka',
#   'gdl': [{'det': 'semantic',
#     'pos': 'pre',
#     'seq': [{'v': 'iti', 'id': 'P230754.3.1.0'}]},
#    {'v': 'šeg₁₂',
#     'id': 'P230754.3.1.1',
#     'break': 'damaged',
#     'ho': '1',
#     'delim': '-',
#     'hc': '1'},
#    {'v': 'a',
#     'id': 'P230754.3.1.2',
#     'breakStart': '1',
#     'o': '[',
#     'break': 'missing',
#     'delim': '-'},
#    {'v': 'ka',
#     'id': 'P230754.3.1.3',
#     'break': 'missing',
#     'o': ']',
#     'breakEnd': 'P230754.3.1.2'}],
#   'cf': 'Šega',
#   'gw': '1',
#   'sense': '1',
#   'norm0': 'Šega,ak.a',
#   'pos': 'MN',
#   'epos': 'MN',
#   'base': '{iti}šeg₁₂-a',
#   'morph': '~,ak.a',
#   'id_text': 'P230754'},
#  {'lang': 'sux',
#   'form': 'kug-bi',
#   'delim': '',
#   'gdl': [{'v': 'kug', 'id': 'P230754.4.1.0', 'delim': '-'},
#    {'v': 'bi', 'id': 'P230754.4.1.1'}],
#   'cf': 'kug',
#   'gw': 'metal',
#   'sense': 'metal, silver',
#   'norm0': 'kug,bi',
#   'pos': 'N',
#   'epos': 'N',
#   'base': 'kug',
#   'morph': '~,bi',
#   'id_text': 'P230754'},
#  {'lang': 'sux',
#   'form': 'i₃-la₂-e',
#   'gdl': [{'v': 'i₃',
#     'id': 'P230754.4.2.0',
#     'break': 'damaged',
#     'ho': '1',
#     'delim': '-',
#     'hc': '1'},
#    {'v': 'la₂',
#     'id': 'P230754.4.2.1',
#     'breakStart': '1',
#     'o': '[',
#     'break': 'missing',
#     'delim': '-'},
#    {'v': 'e',
#     'id': 'P230754.4.2.2',
#     'break': 'missing',
#     'o': ']',
#     'breakEnd': 'P230754.4.2.1'}],
#   'cf': 'la',
#   'gw': 'hang',
#   'sense': 'to weigh, weigh (out), pay',
#   'norm0': 'V:la;e',
#   'pos': 'V/t',
#   'epos': 'V/t',
#   'base': 'la₂',
#   'morph': 'V:~;e',
#   'id_text': 'P230754'},
#  {'lang': 'sux',
#   'form': 'tukum-bi',
#   'gdl': [{'v': 'tukum',
#     'id': 'P230754.5.1.0',
#     'break': 'damaged',
#     'ho': '1',
#     'delim': '-',
#     'hc': '1'},
#    {'v': 'bi',
#     'id': 'P230754.5.1.1',
#     'breakStart': '1',
#     'o': ']',
#     'break': 'missing',
#     'breakEnd': 'P230754.5.1.1'}],
#   'cf': 'tukumbi',
#   'gw': 'if',
#   'sense': 'if',
#   'norm0': 'tukumbi',
#   'pos': 'CNJ',
#   'epos': 'CNJ',
#   'base': 'tukum-bi',
#   'morph': '~',
#   'id_text': 'P230754'},
#  {'lang': 'sux',
#   'form': '{iti}šeg₁₂-a-ka',
#   'gdl': [{'det': 'semantic',
#     'pos': 'pre',
#     'seq': [{'v': 'iti',
#       'id': 'P230754.6.1.0',
#       'breakStart': '1',
#       'o': ']',
#       'break': 'missing',
#       'breakEnd': 'P230754.6.1.0'}]},
#    {'v': 'šeg₁₂',
#     'id': 'P230754.6.1.1',
#     'break': 'damaged',
#     'ho': '1',
#     'delim': '-'},
#    {'v': 'a', 'id': 'P230754.6.1.2', 'break': 'damaged', 'delim': '-'},
#    {'v': 'ka', 'id': 'P230754.6.1.3', 'break': 'damaged', 'hc': '1'}],
#   'cf': 'Šega',
#   'gw': '1',
#   'sense': '1',
#   'norm0': 'Šega,ak.a',
#   'pos': 'MN',
#   'epos': 'MN',
#   'base': '{iti}šeg₁₂-a',
#   'morph': '~,ak.a',
#   'id_text': 'P230754'}]

# %%
word_df = pd.DataFrame(lemm_l)
word_df = word_df.fillna('')      # replace NaN (Not a Number) with empty string
word_df[["form", "cf", "gw", "pos", "id_text"]]
# Out:
#               form       cf     gw  pos  id_text
# 0  {iti}šeg₁₂-a-ka     Šega      1   MN  P230754
# 1           kug-bi      kug  metal    N  P230754
# 2         i₃-la₂-e       la   hang  V/t  P230754
# 3         tukum-bi  tukumbi     if  CNJ  P230754
# 4  {iti}šeg₁₂-a-ka     Šega      1   MN  P230754
