# %% [markdown]
# # Visualizing Topic Model
#
# This is a work-in-progress Notebook providing different types of visualization for a topic model. The first visualization (`pyLDAvis`) allows a researcher to interact with the *vocabulary* of the corpus and its distribution over topics. pyLDAvis is an out-of-the-box package, a wrapper around the R-library `LDAvis`.
#
# The second visualization employs the `bokeh` library and allows a researcher to interact with (and inspect) *documents* and the distribution of topics over documents.
#
# The data used in this notebook are scraped from [ORACC](http://oracc.org). Most of the techniques used here, however, may be applied to any set of documents.
#
# # Dependencies and Versions
# pyLDAvis 2.0 is incompatible with Pandas 0.19 (check for pyLDAvis 2.1.0 or later). The MDS and tSNE computations necessary for plotting the distribution of documents in the topic model need scikit-learn 0.18. This notebook was written for Python 3.5.

# %%
import pandas as pd
import glob
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # Read in Data
# First read the directory with the relevant texts. These files contain lemmatization in ORACC style, e.g. `lugal[king]N`. The documents list lemmatizations per line.

# %%
path =r'data/' # use your path
allFiles = glob.glob(path +"saao" + "*.txt")
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
data = pd.concat(list_)
data.head()
# Out:
#               id_text                                          text_name  \
# 0  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# 1  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# 2  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# 3  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# 4  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
#
#                                              version l_no  \
# 0  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...  o 1
# 1  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...  o 2
# 2  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...  o 3
# 3  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...  o 4
# 4  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...  o 5
#
#                                                 text
# 0  awātu[word]N šarru[king]N ana[to]PRP Aššur-šar...
# 1  šulmu[completeness]N ana[to]PRP libbu[interior...
# 2  ša[that]REL šapāru[send]V mā[saying]PRP māru[s...
# 3  Muskaya[Phrygian]EN ina[in]PRP muhhu[skull]N a...
# 4  Quwaya[from-Quwe]EN ša[that]REL Urik[1]PN ana[...

# %% [markdown]
# # Collapse lines to one row per document
# In order to transform this DataFrame into a proper input for topic modeling we need to discard the columns `version` and `l_no` and concatenate all the text that belongs to one document in a single row. Some lines have no content in the `text` column - these lines need to be dropped.
#
# First select the relevant columns and drop the rows that have no text content.

# %%
data = data[['id_text', 'text_name', 'text']]
data = data.dropna()
data.head()
# Out:
#               id_text                                          text_name  \
# 0  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# 1  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# 2  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# 3  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# 4  saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
#
#                                                 text
# 0  awātu[word]N šarru[king]N ana[to]PRP Aššur-šar...
# 1  šulmu[completeness]N ana[to]PRP libbu[interior...
# 2  ša[that]REL šapāru[send]V mā[saying]PRP māru[s...
# 3  Muskaya[Phrygian]EN ina[in]PRP muhhu[skull]N a...
# 4  Quwaya[from-Quwe]EN ša[that]REL Urik[1]PN ana[...

# %% [markdown]
# Group the rows by `id_text` and apply the `join` function to the `text` column. Transform the aggregated data into a new DataFrame.

# %%
docs = data['text'].groupby(data['id_text']).apply(' '.join)
df = pd.DataFrame(docs)
df.head()
# Out:
#                                                                  text
# id_text
# saao/saa01/P224485  awātu[word]N šarru[king]N ana[to]PRP Aššur-šar...
# saao/saa01/P313416  ana[to]PRP šarru[king]N bēlu[lord]N ardu[slave...
# saao/saa01/P313417  ana[to]PRP šarru[king]N bēlu[lord]N ardu[slave...
# saao/saa01/P313425  ana[to]PRP šarru[king]N bēlu[lord]N ardu[slave...
# saao/saa01/P313427  ana[to]PRP šarru[king]N bēlu[lord]N ardu[slave...

# %% [markdown]
# Create a DataFrame of `id_text` and `text_name` equivalencies, with `id_text` set as index (row names). Then merge these DataFrames using the indexes.

# %%
ids_names = data[['id_text','text_name']].drop_duplicates().set_index('id_text')
df = pd.merge(ids_names, df, right_index=True, left_index=True)
df.head()
# Out:
#                                                             text_name  \
# id_text
# saao/saa01/P224485  SAA 01 001. Midas Of Phrygia Seeks Detente (NL...
# saao/saa01/P313416  SAA 01 158. Gold and Silver Objects Sent to th...
# saao/saa01/P313417      SAA 01 233. More Land to Bel-duri (CT 53 002)
# saao/saa01/P313425      SAA 01 179. No Iron to the Arabs! (CT 53 010)
# saao/saa01/P313427  SAA 01 152. The Affair of Gidgidanu and His Br...
#
#                                                                  text
# id_text
# saao/saa01/P224485  awātu[word]N šarru[king]N ana[to]PRP Aššur-šar...
# saao/saa01/P313416  ana[to]PRP šarru[king]N bēlu[lord]N ardu[slave...
# saao/saa01/P313417  ana[to]PRP šarru[king]N bēlu[lord]N ardu[slave...
# saao/saa01/P313425  ana[to]PRP šarru[king]N bēlu[lord]N ardu[slave...
# saao/saa01/P313427  ana[to]PRP šarru[king]N bēlu[lord]N ardu[slave...

# %%
from gensim import corpora, models, utils
import gensim

# %% [markdown]
# # Read in the texts
# [For test purposes one may select only the first 100 documents. Remove the hashmark (#) from the first line of the following cell if you wish to do that]

# %%
#df = df[:100]
documents = df['text']

# %% [markdown]
# #  Tokenize
#
# Texts are tokenized by white space. The output variable `texts` is a list of lists, where each list represents a document.

# %%
texts = [[word for word in document.lower().split()] for document in documents]

# %% [markdown]
# # POS-filter
# The variable `posfilter` holds the last two characters of lemmatized words with allowed Part of Speech tags. If, for instance, you wish to select Verbs, Adjectives, and Nouns (in Akkadian), posfilter will be `[']n', 'aj', ']v']`. Note that one-character pos-tags need the right bracket!
# The POS labels are:
# * "n", #Nouns
# * "v", #Verbs
# * "aj", #Adjectives
# * "av", #Adverbs
# * "an", #Agricultural Name
# * "cn", #Celestial Name
# * "dn", #Divine Name
# * "en", #Ethnicity Name
# * "fn", #Field Name
# * "gn", #Geographical Name (lands, etc.)
# * "ln", #Lineage Name (ancestral clan)
# * "mn", #Month Name
# * "on", #Object Name
# * "pn", #Personal Name
# * "qn", #Quarter (of a city) Name
# * "rn", #Royal Name
# * "sn", #Settlement Name
# * "tn", #Temple Name
# * "wn", #Watercourse Name
# * "yn", #Year Name
# * "nu", #Numeral

# %%
posfilter = [']n', ']v', 'aj']
#include nouns, verbs, and adjectives, not numerals, prepositions or proper nouns
texts = [[word for word in text if word[-2:] in posfilter] for text in texts]

# %% [markdown]
# # Stop words
#
# Stop words are very frequent words that are not able to distinguish between topics. This includes, for instance, prepositions - but can also be filtered out by the POS filter. The following nouns and verbs are too frequent to contribute to the analysis.

# %%
stoplist = [
'šarru[king]n',
'bēlu[lord]n',
'libbu[interior]n',
'muhhu[skull]n',
'ardu[slave]n',
'šulmu[completeness]n',
'šapāru[send]v',
'alāku[go]v',
'qabû[say]v',
'pānu[front]n',
'māru[son]n',
'bītu[house]n',
'epēšu[do]v',
'wabālu[bring]v',
'šakānu[put]v',
'amāru[see]v',
'bašû[exist]v',
'našû[lift]v',
'izuzzu[stand]v',
'ūmu[day]n',
'ṭābu[good]aj',
'mādu[many]aj',
'nadānu[give]v',
'tadānu[give]v',
'ṣehru[small]aj',
'mimmû[all]n',
'gimru[totality]n',
'gabbu[totality]n',
'šâlu[ask]v',
'šemû[hear]v',
'ūmu[day]n',
'awātu[word]n',
'erēbu[enter]v'
]
texts = [[word for word in text if word not in stoplist] for text in texts]

# %% [markdown]
# # Filter out texts that have too few words left
# Identify texts that have less than 10 lemmas left and use that selection for the list `texts` and for the dataframe `df`.

# %%
bo = [len(text)>9 for text in texts]
df = df[bo]
texts = [texts[i] for i in range(0, len(texts)) if bo[i]]

# %% [markdown]
# How many documents did we start with, and how many do we have left?

# %%
len(bo), len(df)
# Out:
# (3230, 1754)

# %% [markdown]
# # Dictionary
# create the gensim Dictionary and filter for words that are too common or too rare (no_above may be set too low here).

# %%
dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=1, no_above=0.8)
## CHECK - is this done correctly?

# %%
corpus = [dictionary.doc2bow(doc) for doc in texts]

# %% [markdown]
# # Compute the Model
#
# Set the seed, indicate the number of topics and run the model

# %%
seed = 42
np.random.seed(seed)
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel
ntopics = 10
# Running and Training LDA model on the document term matrix.
ldamodel = Lda(corpus, num_topics=ntopics, id2word = dictionary, passes=50)

# %% [markdown]
# List the top words and their probabilities in all topics. Note: the topic numbers here are not the ones used below in the visualizations! (The topics are the same, but not their numbers).

# %%
ldamodel.show_topics(ntopics, formatted = False)
# Out:
# [(0,
#   [('šību[witness]n', 0.22094604698678141),
#    ('manû[unit]n', 0.04763643448024904),
#    ('ṣarpu[silver]n', 0.039774779683397772),
#    ('dīnu[legal-decision]n', 0.039276795591476607),
#    ('dabābu[speak]v', 0.037391489171835664),
#    ('kaspu[silver]n', 0.02929640695012763),
#    ('leqû[take]v', 0.027215565836600418),
#    ('târu[turn]v', 0.026804354071371696),
#    ('kunukku[seal]n', 0.02241758445372468),
#    ('rabû[big-one]n', 0.01690110775052852)]),
#  (1,
#   [('eqlu[field]n', 0.12256813782224285),
#    ('imēru[unit]n', 0.070396660776286674),
#    ('ālu[city]n', 0.027690462636319208),
#    ('hūlu[way]n', 0.023615360542442423),
#    ('zēru[seed(s)]n', 0.022503769903332565),
#    ('kurummatu[ration]n', 0.021129077017512828),
#    ('akālu[eat]v', 0.019287898872452344),
#    ('ummu[mother]n', 0.016550283135139812),
#    ('šattu[year]n', 0.014982185686748722),
#    ('qû[unit]n', 0.014075296816645003)]),
#  (2,
#   [('hurāṣu[gold]n', 0.030144603242483102),
#    ('immeru[sheep]n', 0.027044464876048183),
#    ('karābu[pray]v', 0.021210376512795611),
#    ('dullu[trouble]n', 0.020459758168853943),
#    ('paqādu[entrust]v', 0.017601640906855297),
#    ('šangû[priest]n', 0.015820459103248179),
#    ('alpu[ox]n', 0.015514410240166572),
#    ('ilu[god]n', 0.015228674807472767),
#    ('ṭēmu[(fore)thought]n', 0.012234609739859639),
#    ('ṭūbu[goodness]n', 0.012085300129605776)]),
#  (3,
#   [('karābu[pray]v', 0.028160212460837719),
#    ('mātu[land]n', 0.027638674583958987),
#    ('qātu[hand]n', 0.015048926579738074),
#    ('ālu[city]n', 0.014361830052648678),
#    ('ittu[sign]n', 0.012010476252336965),
#    ('ṣabātu[seize]v', 0.010468436751630304),
#    ('šaṭāru[write]v', 0.010012238053084736),
#    ('aṣû[go-out]v', 0.009709765745880318),
#    ('pû[mouth]n', 0.0092874823961226569),
#    ('lumnu[evil]n', 0.0091572254192832259)]),
#  (4,
#   [('ammatu[unit]n', 0.043580176056978955),
#    ('dullu[trouble]n', 0.034946137683569058),
#    ('rabû[big-one]n', 0.029001654535314659),
#    ('raṣāpu[build]v', 0.018019832455401705),
#    ('mahāru[face]v', 0.017434894807166701),
#    ('abu[father]n', 0.017389840405487356),
#    ('libittu[mudbrick]n', 0.017360938624067273),
#    ('rupšu[width]n', 0.015962164462416384),
#    ('našû[lifted]aj', 0.014693194438275983),
#    ('ēkallu[palace]n', 0.012404721254955892)]),
#  (5,
#   [('ṣābu[people]n', 0.042550403792055706),
#    ('mātu[land]n', 0.029265358598103544),
#    ('ṭēmu[(fore)thought]n', 0.029231924345702404),
#    ('pīhātu[responsibility]n', 0.029143154736271736),
#    ('ēkallu[palace]n', 0.027049247211655719),
#    ('dabābu[speak]v', 0.024876398807628392),
#    ('šipru[sending]n', 0.024586481954114649),
#    ('ṣabātu[seize]v', 0.022107309299257995),
#    ('qātu[hand]n', 0.020123937602089779),
#    ('rabû[big-one]n', 0.018587033144934078)]),
#  (6,
#   [('ṣābu[people]n', 0.040427327735354596),
#    ('dullu[trouble]n', 0.03870817567611716),
#    ('ṭēmu[(fore)thought]n', 0.022249938148794307),
#    ('šipru[sending]n', 0.021194654118954971),
#    ('birtu[fort]n', 0.019824446336150832),
#    ('sahāru[go-around]v', 0.017024606987565548),
#    ('maṣṣartu[observation]n', 0.016856801292380947),
#    ('nāru[river]n', 0.015718877257749342),
#    ('laššu[(there)-is-not]v', 0.014376263914616732),
#    ('egertu[inscribed-tablet]n', 0.014287109776357193)]),
#  (7,
#   [('ilu[god]n', 0.051486012788718026),
#    ('karābu[pray]v', 0.033618600379087218),
#    ('mātu[land]n', 0.027517014246679003),
#    ('balāṭu[live]v', 0.023952218358012561),
#    ('ṭūbu[goodness]n', 0.022196959777993287),
#    ('šīru[flesh]n', 0.014454437281609212),
#    ('rabû[big]aj', 0.014268923321297282),
#    ('šattu[year]n', 0.014136906060169015),
#    ('wadû[know]v', 0.012531361145274311),
#    ('arku[long]aj', 0.010080555792017507)]),
#  (8,
#   [('sisû[horse]n', 0.15447975341709649),
#    ('kūdanu[mule]n', 0.024697477576549109),
#    ('pēthallu[riding-horse]n', 0.023389244002394356),
#    ('maddattu[payment]n', 0.017570472892176402),
#    ('karābu[pray]v', 0.016745154660184922),
#    ('urû[team]n', 0.014579796153381517),
#    ('saddinu[(a-tunic)]n', 0.014427594043812426),
#    ('ṣarpu[silver]n', 0.013989962584479548),
#    ('šaplu[underside]n', 0.012988658587890041),
#    ('nīru[yoke]n', 0.012769235742946252)]),
#  (9,
#   [('ahu[brother]n', 0.026961358374949822),
#    ('ilu[god]n', 0.024992721951695763),
#    ('abu[father]n', 0.024329499068513435),
#    ('maṣṣartu[observation]n', 0.023832933979195888),
#    ('mātu[land]n', 0.022808738535644191),
#    ('naṣāru[guard]v', 0.017114821119778141),
#    ('karābu[pray]v', 0.016845918499122248),
#    ('ṭūbu[goodness]n', 0.014837461859406886),
#    ('pû[mouth]n', 0.013944363438069405),
#    ('ṭēmu[(fore)thought]n', 0.013674775971919451)])]

# %% [markdown]
# # pyLDAvis
# Use pyLDAvis to visualize the topic model. By default, pyLDAvis will order the topics by [prevalence](https://github.com/bmabey/pyLDAvis/issues/59) (topic 1 is the most prevalent topic). That means that the topic numbers in the visualization do not agree with the topic numbers in the lda model. To prevent this behaviour one may use `sort_topics=False` in the `prepare` command. The advantage of ordering the topics by prevalence, however, is that new instances of the lda model are more comparable (that is, the same topic will receive the same number). Note that the library was written in Java for R, and so the numbering in the visualization begins with 1 (not with 0). The topic numbers in the Document/Topic and Topic/Term matrices below will be adjusted to be compatible with the pyLDAvis visualization.
#
# PyLDAvis needs a large output box. The `%%html` lines below create such a box (for the code see [here](http://stackoverflow.com/questions/18770504/resize-ipython-notebook-output-window)).

# %% [markdown]
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
import os
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary, sort_topics=False)
if not os.path.exists('vis'):
    os.makedirs('vis')
pyLDAvis.save_html(vis, 'vis/lda_terms.html')
pyLDAvis.display(vis)
# Out:
# //anaconda/lib/python3.5/site-packages/funcy/decorators.py:56: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   spec = inspect.getargspec(func)
# //anaconda/lib/python3.5/site-packages/funcy/decorators.py:56: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   spec = inspect.getargspec(func)
# //anaconda/lib/python3.5/site-packages/funcy/decorators.py:56: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   spec = inspect.getargspec(func)
# //anaconda/lib/python3.5/site-packages/funcy/decorators.py:56: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   spec = inspect.getargspec(func)
# //anaconda/lib/python3.5/site-packages/funcy/decorators.py:56: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   spec = inspect.getargspec(func)
# //anaconda/lib/python3.5/site-packages/funcy/decorators.py:56: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   spec = inspect.getargspec(func)
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4976146094034249139316062"></div>
# <script type="text/javascript">
#
# var ldavis_el4976146094034249139316062_data = {"lambda.step": 0.01, "R": 30, "tinfo": {"loglift": [30.0, 29.0, 28.0, 27.0, 26.0, 25.0, 24.0, 23.0, 22.0, 21.0, 20.0, 19.0, 18.0, 17.0, 16.0, 15.0, 14.0, 13.0, 12.0, 11.0, 10.0, 9.0, 8.0, 7.0, 6.0, 5.0, 4.0, 3.0, 2.0, 1.0, 1.1054, 1.102, 1.102, 1.102, 1.101, 1.1009, 1.0938, 1.0904, 1.0903, 1.0902, 1.0898, 1.0888, 1.0813, 1.0796, 1.0723, 1.0639, 1.0637, 1.0631, 1.0631, 1.0622, 1.0606, 1.0583, 1.0558, 1.0539, 1.0528, 1.0494, 1.0425, 1.0424, 1.0401, 1.0313, 0.9987, 0.9956, 0.9963, 0.9812, 0.9201, 0.9646, 0.9767, 0.9673, 0.7533, 0.828, 0.6713, 0.7113, 0.7342, 0.7933, 0.417, 0.3393, 0.566, -0.0418, 0.2142, 2.6465, 2.6426, 2.6356, 2.6325, 2.6115, 2.6091, 2.6089, 2.5928, 2.5903, 2.5819, 2.5591, 2.5496, 2.5496, 2.5459, 2.5248, 2.5208, 2.5092, 2.489, 2.489, 2.489, 2.489, 2.4692, 2.4328, 2.4328, 2.4328, 2.4328, 2.4328, 2.4327, 2.4327, 2.4327, 2.4125, 2.4155, 2.3029, 2.3663, 2.311, 2.2038, 2.1437, 2.1846, 2.2247, 2.0571, 2.1216, 2.2065, 1.7763, 1.9414, 1.7018, 1.2465, 1.9817, 1.1414, 1.9598, 0.7396, 0.4, 1.3126, 0.8348, 0.3483, 0.2331, 1.4866, -0.5306, -0.8048, -0.9266, 2.7536, 2.7521, 2.6822, 2.677, 2.6584, 2.6572, 2.6431, 2.6212, 2.6212, 2.6212, 2.6208, 2.6206, 2.6194, 2.603, 2.5655, 2.5646, 2.5646, 2.5645, 2.5643, 2.5642, 2.5536, 2.5461, 2.5434, 2.5067, 2.4936, 2.4907, 2.4637,
 2.092, 2.092, 2.0915, 2.0911, 2.0756, 2.0472, 2.035, 2.0279, 2.0088, 1.9824, 1.939, 1.9438, 1.7751, 1.6864, 1.8968, 1.6859, 1.9811, 1.457, 1.7237, 1.3763, 1.6065, 1.8769, 1.2778, 1.4569, 0.971, 1.5728, 1.5337, 1.1631, 1.5475, 1.6518, 1.3662, 0.9331, 1.185, 0.6345, 0.5435, 0.6249, 1.0832, 0.0002, 0.2179, 1.0108, 1.3593, 0.7311, 0.1398, 0.4691, 2.6375, 2.6363, 2.63, 2.5951, 2.5712, 2.5613, 2.5473, 2.5079, 2.504, 2.503, 2.503, 2.468, 2.468, 2.468, 2.468, 2.468, 2.468, 2.4664, 2.4578, 2.4339, 2.4296, 2.4114, 2.4114, 2.4114, 2.4114, 2.4114, 2.4114, 2.4114, ...

# %% [markdown]
# # Document/Topic Probability
# The function `get_document_topics()` will list the probability of the topics in a single document. In order to get all the topics set the argument `minimum_probability` to zero.

# %%
ldamodel.get_document_topics(corpus[1], minimum_probability=0)
# Out:
# [(0, 0.0028580224841580947),
#  (1, 0.0028572845506738952),
#  (2, 0.97428379584700076),
#  (3, 0.0028572159541097406),
#  (4, 0.0028572124803202367),
#  (5, 0.0028572663513453714),
#  (6, 0.0028572481601745899),
#  (7, 0.0028571824941795456),
#  (8, 0.0028575618164064604),
#  (9, 0.002857209861631333)]

# %% [markdown]
# # Create Document/Topic Probability Table
# In order to create a full Document/Topic probability table we iterate over the entire corpus with the `get_document_topics()` function. This creates a list of list (`list_of_doctopics`) where each list represents the probability of each topic in a document. The probability is represented in a tuple (topic_number, probability). The `list_of_probabilities` preserves only the probabilities. This list of lists is transformed into a DataFrame, whith as index the index of the original DataFrame with the tokenized data.

# %%
list_of_doctopics = [ldamodel.get_document_topics(corpus[i], minimum_probability=0) for i in range(len(corpus))]
list_of_probabilities = [[probability for label,probability in distribution] for distribution in list_of_doctopics]
d_t_df = pd.DataFrame(list_of_probabilities)
d_t_df = d_t_df.set_index(df.index)
d_t_df.head()
# Out:
#                            0         1         2         3         4  \
# id_text
# saao/saa01/P224485  0.001177  0.001177  0.001177  0.001177  0.001177
# saao/saa01/P313416  0.002858  0.002857  0.974284  0.002857  0.002857
# saao/saa01/P313417  0.002222  0.546369  0.002222  0.002223  0.002223
# saao/saa01/P313425  0.061273  0.290515  0.001352  0.001352  0.078106
# saao/saa01/P313427  0.004167  0.004167  0.004168  0.004168  0.129159
#
#                            5         6         7         8         9
# id_text
# saao/saa01/P224485  0.001177  0.989410  0.001177  0.001177  0.001177
# saao/saa01/P313416  0.002857  0.002857  0.002857  0.002858  0.002857
# saao/saa01/P313417  0.120932  0.317141  0.002222  0.002222  0.002222
# saao/saa01/P313425  0.561996  0.001352  0.001352  0.001352  0.001352
# saao/saa01/P313427  0.004168  0.345353  0.004168  0.004167  0.496316

# %% [markdown]
# # Renumber Topics
# Rename the topics `topic_1` to `topic_n` in accordance with the pyLDAvis visualization and add `text_name`.

# %%
topics = ['topic_' + str(i+1) for i in range(ntopics)]
d_t_df.columns = topics
d_t_df['text_name'] = df['text_name']
d_t_df
# Out:
#                      topic_1   topic_2   topic_3   topic_4   topic_5  \
# id_text
# saao/saa01/P224485  0.001177  0.001177  0.001177  0.001177  0.001177
# saao/saa01/P313416  0
# saao/saa19/P393678  SAA 19 049. Should They Cross the River or be ...
# saao/saa19/P393679  SAA 19 019. Favourable Exchange Rate (CTN 5 p....
# saao/saa19/P393680  SAA 19 051. Unable to Take Care of Pack Animal...
# saao/saa19/P393682  SAA 19 195. Wayward Gurreans and Eunuchs (CTN ...
# saao/saa19/P393685  SAA 19 117. Boats Water-Skin Rafts and Accusat...
# saao/saa19/P393688     SAA 19 209. Distributing Fields (CTN 5 p. 205)
# saao/saa19/P393689  SAA 19 202. I Shall Complete my Brother’s Miss...
# saao/saa19/P393690  SAA 19 212. Fragment Mentioning the Town of Re...
# saao/saa19/P393691  SAA 19 124. Sacrifices before Bel and Zarpanit...
# saao/saa19/P393696        SAA 19 021. Works in Turmuna (CTN 5 p. 257)
# saao/saa19/P393702  SAA 19 225. Seed Stored Grain and Barley Given...
# saao/saa19/P393703     SAA 19 226. Copper Cooking Pots (CTN 5 p. 284)
# saao/saa19/P393709      SAA 19 155. Don’t be Negligent (CTN 5 p. 262)
# saao/saa19/P415762  SAA 19 118. Fragment Mentioning Balassu (CTN 5...
#
# [1754 rows x 11 columns]

# %% [markdown]
# # Create Topic / Term table
# This is a table with N rows (the number of topics) and M columns (the number of individual terms in the Dictionary). The table indicates the probability of each term in each topic.

# %%
topic_term = ldamodel.show_topics(ntopics, formatted=False, num_words=len(dictionary))

# %% [markdown]
# The object `topic_term` is a list of list. Each topic is represented by a list of tuples in the form `(word, probability)`. The following code pulls out the probabilities for each word in each topic (`topic_term[i][1]`) and creates a list of DataFrames with the words as index (rows) and the probabilities as the only column. The DataFrames are concatenated to a single DataFrame.

# %%
topic_term_list = [pd.DataFrame(topic_term[i][1]).set_index(0) for i in range(0, ntopics)]
t_t_df_ = pd.concat(topic_term_list, axis=1, ignore_index=True)
t_t_df_.head()
# Out:
#                                   0         1         2         3         4  \
# abati[(meaning-unknown)]n  0.000006  0.000030  0.000034  0.000022  0.000047
# abbūtu[fatherhood]n        0.000006  0.000030  0.000034  0.000880  0.000047
# abiktu[defeat]n            0.000006  0.000030  0.000034  0.000022  0.000047
# abku[captive]n             0.000006  0.000030  0.000704  0.000244  0.000047
# abnu[stone]n               0.000006  0.000325  0.003174  0.000022  0.000515
#
#                                   5         6         7         8         9
# abati[(meaning-unknown)]n  0.000018  0.000021  0.000316  0.000055  0.000021
# abbūtu[fatherhood]n        0.001065  0.000021  0.001167  0.000058  0.000310
# abiktu[defeat]n            0.000377  0.000022  0.000316  0.000055  0.000021
# abku[captive]n             0.000018  0.000021  0.000029  0.000055  0.000021
# abnu[stone]n               0.000018  0.000021  0.000382  0.000055  0.000322

# %% [markdown]
# Rename the columns (`0` becomes `topic_1` etc) and Transpose to Topic/Term matrix.

# %%
t_t_df_.columns = topics
t_t_df = t_t_df_.T
t_t_df
# Out:
#           abati[(meaning-unknown)]n  abbūtu[fatherhood]n  abiktu[defeat]n  \
# topic_1                    0.000006             0.000006         0.000006
# topic_2                    0.000030             0.000030         0.000030
# topic_3                    0.000034             0.000034         0.000034
# topic_4                    0.000022             0.000880         0.000022
# topic_3          0.012085
# topic_4          0.000026
# topic_5          0.000047
# topic_6          0.000018
# topic_7          0.000021
# topic_8          0.022197
# topic_9          0.000464
# topic_10         0.014837
#
# [10 rows x 2717 columns]

# %%
#just checking
t_t_df['ēkallu[palace]n']
# Out:
# topic_1     0.003254
# topic_2     0.011845
# topic_3     0.004976
# topic_4     0.008523
# topic_5     0.012405
# topic_6     0.027049
# topic_7     0.005965
# topic_8     0.002141
# topic_9     0.008362
# topic_10    0.003936
# Name: ēkallu[palace]n, dtype: float64

# %% [markdown]
# # Visualize the Documents 1: Using MDS
# While pyLDAvis is an excellent tool for exploring the topic/term aspect of a topic model (the words and their probabilities in each topic) it does not provide access to the document/topic aspect (the probability distribution of topics in each document). The visualization below plots all the documents according to their (cosine) distances (using Multi-Dimensional Scaling) in the Document/Term DataFrame. Each document (data point in the visualization) is colored according to the most prevalent topic and the size of the dot represents the probability of the most prevalent topic in that document.

# %%
from scipy.spatial.distance import pdist, squareform
from sklearn.manifold import MDS

# %% [markdown]
# Compute the distances between each of the documents. Use either the Document/Topic Dataframe or the Document/Term Dataframe (constructed below) to measure distance.

# %%
cv = CountVectorizer(analyzer='word', token_pattern=r'[^ ]+', vocabulary=list(t_t_df.columns.values))
dtm = cv.fit_transform(df['text'])
dtm_df = pd.DataFrame(dtm.toarray(), columns = cv.get_feature_names(), index = df.index.values)
dtm_df.head()
# Out:
#                     abati[(meaning-unknown)]n  abbūtu[fatherhood]n  \
# saao/saa01/P224485                          0                    0
# saao/saa01/P313416                          0                    0
# saao/saa01/P313417                          0                    0
# saao/saa01/P313425                          0                    0
# saao/saa01/P313427                          0                    0
#
#                     abiktu[defeat]n  abku[captive]n  abnu[stone]n  \
# saao/saa01/P224485                0               0             0
# saao/saa01/P313416                0               0             1
# saao/saa01/P313417                0               0             0
# saao/saa01/P313425                0               0             0
# saao/saa01/P313427                0               0             0
#
#                     abu[father]n  abullu[(city)-gate]n  abāku[lead-away]v  \
# saao/saa01/P224485             0                     0                  0
# saao/saa01/P313416             0                     0                  0
# saao/saa01/P313417             0                     0                  0
# saao/saa01/P313425             0                     1                  0
# saao/saa01/P313427             0                     2                  0
#
#                     abālu[dry-(up)]v  abāru[(the-metal)-lead]n  \
# saao/saa01/P224485                 0                         0
# saao/saa01/P313416                 0                         0
# saao/saa01/P313417                 0                         0
# saao/saa01/P313425                 0                         0
# saao/saa01/P313427                 0                         0
#
#                          ...         ṭābtu[salt]n  ṭābtānu[doer-of-good]n  \
# saao/saa01/P224485       ...                    0                       0
# saao/saa01/P313416       ...                    0                       0
# saao/saa01/P313417       ...                    0                       0
# saao/saa01/P313425       ...                    0                       0
# saao/saa01/P313427       ...                    0                       0
#
#                     ṭābtūtu[goodwill]n  ṭātu[bribe]n  \
# saao/saa01/P224485                   0             0
# saao/saa01/P313416                   0             0
# saao/saa01/P313417                   0             0
# saao/saa01/P313425                   0             0
# saao/saa01/P313427                   0             0
#
#                     ṭēhu[immediate-vicinity]n  ṭēmu[(fore)thought]n  \
# saao/saa01/P224485                          0                     1
# saao/saa01/P313416                          0                     0
# saao/saa01/P313417                          0                     2
# saao/saa01/P313425                          0                     0
# saao/saa01/P313427                          0                     0
#
#                     ṭēmūtu[of-order]n  ṭīdu[clay]n  ṭīmu[yarn]n  \
# saao/saa01/P224485                  0            0            0
# saao/saa01/P313416                  0            0            0
# saao/saa01/P313417                  0            0            0
# saao/saa01/P313425                  0            0            0
# saao/saa01/P313427                  0            0            0
#
#                     ṭūbu[goodness]n
# saao/saa01/P224485                0
# saao/saa01/P313416                0
# saao/saa01/P313417                0
# saao/saa01/P313425                0
# saao/saa01/P313427                0
#
# [5 rows x 2717 columns]

# %%
dist = squareform(pdist(dtm_df, 'cosine'))

# %% [markdown]
# Compute the position of each document using Multi-Dimensional Scaling. The variable `pos` holds the `x` and `y`  coordinates.

# %%
mds = MDS(n_components=2, max_iter=3000,
       random_state=seed, dissimilarity="precomputed", n_jobs=1)
pos = mds.fit_transform(dist)

# %% [markdown]
# Create a list of x values (coordinates) and a list of y values.

# %%
dms_x = [x for x, y in pos]
dms_y = [y for x, y in pos]

# %% [markdown]
# Create lists of the most prevalent topic, the probability of the most prevalent topic, and the text name for each document. These lists are used in the Bokeh visualization.

# %%
prevalent_topic = d_t_df.drop('text_name', axis=1).idxmax(axis=1)
probability = [d_t_df.ix[i][prevalent_topic[i]] for i in range(0, len(corpus))]
text_name = [name for name in d_t_df['text_name']]

# %%
len(prevalent_topic)
# Out:
# 1754

# %% [markdown]
# # Define Colors
#
# Create a palette of the length `ntopics` and link that to topic numbers in the dictionary `colormap`. The list `colors` indicates the proper color for each document (determined by the most prevalent topic).

# %%
from bokeh import palettes
#color_pal = palettes.all_palettes['Viridis'][ntopics]
#try to use d3['Category20']
#color_pal = ["#023FA5","#7D87B9","#BEC1D4","#D6BCC0","#BB7784","#FFFFFF",
#             "#4A6FE3","#8595E1","#B5BBE3","#E6AFB9","#E07B91","#D33F6A", 
#             "#11C638","#8DD593","#C6DEC7","#EAD3C6","#F0B98D","#EF9708", 
#             "#0FCFC0","#9CDED6","#D5EAE7","#F3E1EB","#F6C4E1","#F79CD4"]
# color palette found in http://graphicdesign.stackexchange.com/questions/3682/where-can-i-find-a-large-palette-set-of-contrasting-colors-for-coloring-many-d
#topics = ['topic_' + str(i) for i in range(1, ntopics+1)]
#colormap = dict(zip(topics, color_pal))

colormap = {'topic_1': "orange", 'topic_2': "olive", 'topic_3': "firebrick", 
          'topic_4': "gold", 'topic_5': "red", 'topic_6': "fuchsia", 'topic_7': "green", 
          'topic_8': "blue", 'topic_9': "purple", 'topic_10': "aqua", 'topic_11': "yellow", 
          'topic_12': "indigo", 'topic_13': "blueviolet", 'topic_14': "beige", 'topic_15':"navy", 'topic_16': 'chocolate',
           'topic_17': 'azure', 'topic_18': 'coral', 'topic_19': 'crimson', 'topic_20': 'darkblue', 'topic_21': 'darkkhaki', 
            'topic_22': 'darkseagreen', 'topic_23': 'darkturquoise', 'topic_24': 'deeppink', 'topic_25': 'black'}
#colormap = OrderedDict(colormap)
colors = [colormap[n] for n in prevalent_topic]
color_list = [colormap['topic_' + str(i)] for i in range(1, ntopics+1)]

# %% [markdown]
# Import Bokeh and create data source. ColumnDataSource is a Bokeh function that creates a `source`, a database that holds information about each of the data points that are plotted. Bokeh can use the `source` to hold `x` and `y` coordinates; to select color, shape, or size; to include data or metadata in tooltips, to create a link to a web page, etc.

# %%
from bokeh.io import vform
from bokeh.models import ColumnDataSource, OpenURL, TapTool, HoverTool, CustomJS
from bokeh.models.widgets import Slider
from bokeh.plotting import figure, output_file, output_notebook, show
from bokeh.layouts import widgetbox, column

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="22016be7-1606-4d45-97b5-000e40f43425">Loading BokehJS ...</span>
#     </div>

# %%
source_mds = ColumnDataSource(data=dict(
        x=dms_x,
        y=dms_y,
        id_text=list(d_t_df.index.values),
        size = probability/max(probability)*25,
        probability = probability,
        topic = prevalent_topic,
        color = colors,
        orig_color = color_list,
        text_name = text_name
    ))

# %% [markdown]
# Draw the visualization. The visualization provides various tools for further exploration:
# - tooltips (provides topic, probability, text name and URL)
# - box zoom
# - wheel zoom
# - pan
# - reset
# - link to document edition
# - save the visualization
#
# In addition, the visualization has two sliders that allow the user to select two topics.

# %%
p = figure(
    plot_width=1000, plot_height=1000,
    tools="tap,pan,wheel_zoom,box_zoom,reset,save", 
    title="Topic Distribution MDS\nSize of the circle represents prevalence of the topic")
p.add_tools(HoverTool(
        tooltips=[
            ("url", "http://oracc.org/" + "@id_text"),
            (("topic, probability"), ("@topic, @probability")),
            ("text name", "@text_name")
        ]
        ))


p.circle('x', 'y', color='color', fill_alpha=.5, size='size', source=source_mds)
p.axis.visible = False

callback = CustomJS(args=dict(source=source_mds), code = """
    var data = source.get('data');
    var current_topic_1 = topic1.value;
    var current_topic_2 = topic2.value;
    x = data['x']
    y = data['y']
    col = data['color']
    topic = data['topic']

    orig_color = data['orig_color']
    for (i = 0; i < x.length; i++) {
        if (topic[i].substring(6) == current_topic_1) {
            col[i] = orig_color[current_topic_1 - 1]
        } else {
            col[i] = 'grey'
        }
        if (topic[i].substring(6) == current_topic_2) {
            col[i] = orig_color[current_topic_2 - 1]
        }
    }
    source.trigger('change');
""")

topic_slider = Slider(start=1, end = ntopics, value=1, step=1, title = 'Topic', callback=callback)
callback.args['topic1'] = topic_slider
topic_slider2 = Slider(start=1, end = ntopics, value=1, step=1, title = 'Topic', callback=callback)
callback.args['topic2'] = topic_slider2

url = "http://oracc.museum.upenn.edu/@id_text"

taptool = p.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(column(topic_slider, topic_slider2, p))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="3408a88c-419e-4b64-8666-44a809acdc24"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#3408a88c-419e-4b64-8666-44a809acdc24").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3408a88c-419e-4b64-8666-44a809acdc24");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3408a88c-419e-4b64-8666-44a809acdc24' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"41a99b04-0a22-4475-b4eb-7954e1e424a2":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e4d33d4-9eaf-4be9-859a-62c971638da3","type":"Circle"},{"attributes":{},"id":"eb9f9d61-8fce-4bd8-ad09-df88aed34ef9","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"263f027f-b6de-41ec-a5cd-fdbf21aa4ec0","type":"Slider"}]},"id":"e2a01517-71ba-4255-991f-002867673a34","type":"WidgetBox"},{"attributes":{"callback":null,"plot":{"id":"ce23faf9-0927-423a-ac13-edf552fc0704","subtype":"Figure","type":"Plot"},"tooltips":[["url","http://oracc.org/@id_text"],["topic, probability","@topic, @probability"],["text name","@text_name"]]},"id":"24bd7ed2-1169-42f5-ad49-e1858bfb0856","type":"HoverTool"},{"attributes":{},"id":"3b5ab74d-a20e-4272-a96d-bbad31eb4cb8","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"ce23faf9-0927-423a-ac13-edf552fc0704","subtype":"Figure","type":"Plot"},"ticker":{"id":"174ff0e8-220b-4c37-a9a5-6189c6f7fd20","type":"BasicTicker"}},"id":"1f271e72-f353-4561-b4a3-473cda1f04d7","type":"Grid"},{"attributes":{"children":[{"id":"d993c8bd-e748-4d64-91c2-0c7bcfae99b7","type":"Slider"}]},"id":"24cc8e52-a6f8-4943-ac3e-3707d7ef5310","type":"WidgetBox"},{"attributes":{"callback":{"id":"454f34a7-5184-4b2a-9599-f6124cf48190","type":"OpenURL"},"plot":{"id":"ce23faf9-0927-423a-ac13-edf552fc0704","subtype":"Figure","type":"Plot"}},"id":"8ccf9c94-1a57-437f-9b9d-fb777f14c47d","type":"TapTool"},{"attributes":{"plot":{"id":"ce23faf9-0927-423a-ac13-edf552fc0704","subtype":"Figure","type":"Plot"}},"id":"22a19ab2-a6cf-4643-ac73-d95016d6ce7d","type":"SaveTool"},{"attributes":{"formatter":{"id":"77b49f88-7f4d-44b1-b809-b4549c444cf2","type":"BasicTickFormatter"},"plot":{"id":"ce23faf9-0927-423a-ac13-edf552fc0704","subtype":"Figure","type":"Plot"},"ticker":{"id":"e34540aa-728f-4c33-aa97-91300a18bdea","type":"BasicTicker"},"visible":false},"id":"ce78c2ef-c541-4860-a42e-8659d3258e01","type":"LinearAxis"},{"attributes":{"plot":{"id":"ce23faf9-0927-423a-ac13-edf552fc0704","subtype":"Figure","type":"Plot"}},"id":"cb74fd98-28ba-40b4-a70a-3ae9894d2fe6","type":"ResetTool"},{"attributes":{"callback":null},"id":"a46e82f4-b8d9-4fff-9522-a537b3f5a72e","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_color":{"field":"color"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3439388c-3569-46b1-ae51-bb8226504782","type":"Circle"},{"attributes":{"plot":{"id":"ce23faf9-0927-423a-ac13-edf552fc0704","subtype":"Figure","type":"Plot"}},"id":"4285bb83-5960-4b93-be74-30e0b3e6a0de","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"9cc3e7e8-abc9-452b-b058-7db0d76c4b14","type":"BoxAnnotation"},"plot":{"id":"ce23faf9-0927-423a-ac13-edf552fc0704","subtype":"Figure","type":"Plot"}},"id":"22bec1bd-cdc2-4782-9fae-42e8a10023bd","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"Topic Distribution MDS\nSize of the circle represents prevalence of the topic"},"id":"6e72a3ab-68ca-4544-866c-129a36eedad1","type":"Title"},{"attributes":{"callback":{"id":"625df26b-e7d0-4562-b920-2c8698cba995","type":"CustomJS"},"end":10,"start":1,"step":1,"title":"Topic","value":1},"id":"d993c8bd-e748-4d64-91c2-0c7bcfae99b7","type":"Slider"},{"attributes":{"callback":{"id":"625df26b-e7d0-4562-b920-2c8698cba995","type":"CustomJS"},"end":10,"start":1,"step":1,"title":"Topic","value":1},"id":"263f027f-b6de-41ec-a5cd-fdbf21aa4ec0","type":"Slider"},{"attributes":{},"id":"77b49f88-7f4d-44b1-b809-b4549c444cf2","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"ce78c2ef-c541-4860-a42e-8659d3258e01","type":"LinearAxis"}],"left":[{"id":"492b66bd-f2ae-402b-94e4-fd64304a20e8","type":"LinearAxis"}],"plot_height":1000,"plot_width":1000,"renderers":[{"id":"ce78c2ef-c541-4860-a42e-8 ...

# %% [markdown]
# ## Alternative: plotting based on Document/Topic table
# The following visualization uses the same approach, but takes the document/topic table as the basis for distance measurements. Documents that share approximately the same distribution of topics will be plotted n the same region. Since the sum of each row in the document/topic table is 1 the distance matrix is computed with euclidean distance (not cosine).

# %%
dist = squareform(pdist(d_t_df.drop('text_name', axis=1)))

# %%
mds = MDS(n_components=2, max_iter=3000,
       random_state=seed, dissimilarity="precomputed", n_jobs=1)
pos = mds.fit_transform(dist)

# %%
mds2_x = [x for x, y in pos]
mds2_y = [y for x, y in pos]
len(mds2_x)
# Out:
# 1754

# %%
source_mds2 = ColumnDataSource(data=dict(
        x=mds2_x,
        y=mds2_y,
        id_text=list(d_t_df.index.values),
        size = probability/max(probability)*25,
        probability = probability,
        topic = prevalent_topic,
        color = colors,
        orig_color = color_list,
        text_name = text_name
    ))

# %%
p = figure(
    plot_width=1000, plot_height=1000,
    tools="tap,pan,wheel_zoom,box_zoom,reset,save", 
    title="Topic Distribution MDS\nSize of the circle represents prevalence of the topic")
p.add_tools(HoverTool(
        tooltips=[
            ("url", "http://oracc.org/" + "@id_text"),
            (("topic, probability"), ("@topic, @probability")),
            ("text name", "@text_name")
        ]
        ))

p.circle('x', 'y', color='color', fill_alpha=0.5, size='size', source=source_mds2)
p.axis.visible = False

callback = CustomJS(args=dict(source=source_mds2), code = """
    var data = source.get('data');
    var current_topic_1 = topic1.value;
    var current_topic_2 = topic2.value;
    x = data['x']
    y = data['y']
    col = data['color']
    topic = data['topic']

    orig_color = data['orig_color']
    for (i = 0; i < x.length; i++) {
        if (topic[i].substring(6) == current_topic_1) {
            col[i] = orig_color[current_topic_1 - 1]
        } else {
            col[i] = 'grey'
        }
        if (topic[i].substring(6) == current_topic_2) {
            col[i] = orig_color[current_topic_2 - 1]
        }
    }
    source.trigger('change');
""")

topic_slider = Slider(start=1, end = ntopics, value=1, step=1, title = 'Topic', callback=callback)
callback.args['topic1'] = topic_slider
topic_slider2 = Slider(start=1, end = ntopics, value=1, step=1, title = 'Topic', callback=callback)
callback.args['topic2'] = topic_slider2

url = "http://oracc.museum.upenn.edu/@id_text"

taptool = p.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(column(topic_slider, topic_slider2, p))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="3210622e-aa28-4bfb-b1eb-7629cfdbd81e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#3210622e-aa28-4bfb-b1eb-7629cfdbd81e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3210622e-aa28-4bfb-b1eb-7629cfdbd81e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3210622e-aa28-4bfb-b1eb-7629cfdbd81e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a28a9c09-3008-465d-a780-89f600b6b819":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","id_text","color","size","text_name","orig_color","topic","x","probability"],"data":{"color":["green","firebrick","olive","fuchsia","aqua","olive","red","green","blue","fuchsia","fuchsia","fuchsia","fuchsia","fuchsia","fuchsia","fuchsia","fuchsia","green","blue","olive","firebrick","fuchsia","gold","green","fuchsia","red","fuchsia","green","firebrick","red","firebrick","green","green","green","green","olive","aqua","green","firebrick","red","gold","fuchsia","fuchsia","fuchsia","green","green","green","red","gold","red","fuchsia","aqua","red","blue","fuchsia","aqua","red","fuchsia","fuchsia","blue","red","gold","olive","fuchsia","olive","gold","green","green","green","purple","red","green","green","green","green","red","purple","green","firebrick","green","purple","green","aqua","fuchsia","red","purple","firebrick","fuchsia","firebrick","red","red","aqua","blue","fuchsia","olive","green","olive","green","green","fuchsia","green","red","purple","green","fuchsia","fuchsia","green","firebrick","green","red","green","firebrick","firebrick","red","fuchsia","fuchsia","fuchsia","green","green","green","red","red","firebrick","green","green","green","green","green","blue","green","red","fuchsia","olive","fuchsia","fuchsia","fuchsia","fuchsia","olive","olive","green","green","fuchsia","fuchsia","red","green","gold","fuchsia","firebrick","fuchsia","fuchsia","fuchsia","purple","green","green","fuchsia","green","green","olive","green","gold","green","fuchsia","fuchsia","green","green","red","fuchsia","green","fuchsia","green","fuchsia","green","aqua","green","green","fuchsia","fuchsia","fuchsia","green","green","green","red","green","fuchsia","green","green","fuchsia","fuchsia","green","fuchsia","fuchsia","olive","green","green","fuchsia","green","fuchsia","green","fuchsia","aqua","purple","fuchsia","aqua","fuchsia","green","fuchsia","fuchsia","purple","red","green","green","green","green","purple","fuchsia","fuchsia","firebrick","green","firebrick","fuchsia","fuchsia","fuchsia","green","green","green","blue","green","firebrick","fuchsia","green","green","olive","olive","green","gold","purple","fuchsia","olive","green","fuchsia","firebrick","green","green","orange","fuchsia","fuchsia","fuchsia","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","olive","olive","olive","orange","orange","orange","orange","olive","olive","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","olive","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","orange","ora ...

# %% [markdown]
# # Visualize the Documents 2: Using TSNE

# %%
from sklearn.manifold import TSNE

# %% [markdown]
# # TSNE based on Document/Term Matrix (Cosine distance)
#
# Cosine distances have been computed earlier; the matrix is stored in the variable `dist`.

# %%
X = dist
tsne = TSNE(n_components = 2, random_state=0, metric="precomputed")
X_tsne = tsne.fit_transform(X)

# %%
tsne_x = [x for x, y in X_tsne]
tsne_y = [y for x, y in X_tsne]

# %%
source_tsne = ColumnDataSource(data=dict(
        x=tsne_x,
        y=tsne_y,
        id_text=list(d_t_df.index.values),
        size = probability/max(probability)*25,
        probability = probability,
        topic = prevalent_topic,
        color = colors,
        orig_color = color_list,
        text_name = text_name
    ))

# %%
p = figure(
    plot_width=800, plot_height=800,
    tools="tap,pan,wheel_zoom,box_zoom,reset,save", 
    title="Topic Distribution tSNE.\nSize of the circle represents prevalence of the topic")
p.add_tools(HoverTool(
        tooltips=[
            ("url", "http://oracc.org/" + "@id_text"),
            (("topic, probability"), ("@topic, @probability")),
            ("text name", "@text_name")
        ]
        ))


p.circle('x', 'y', color='color', fill_alpha=0.5, size='size', source=source_tsne)
p.axis.visible = False

callback = CustomJS(args=dict(source=source_tsne), code = """
    var data = source.get('data');
    var current_topic_1 = topic1.value;
    var current_topic_2 = topic2.value;
    x = data['x']
    y = data['y']
    col = data['color']
    topic = data['topic']

    orig_color = data['orig_color']
    for (i = 0; i < x.length; i++) {
        if (topic[i].substring(6) == current_topic_1) {
            col[i] = orig_color[current_topic_1 - 1]
        } else {
            col[i] = 'grey'
        }
        if (topic[i].substring(6) == current_topic_2) {
            col[i] = orig_color[current_topic_2 - 1]
        }
    }
    source.trigger('change');
""")

topic_slider = Slider(start=1, end = ntopics, value=1, step=1, title = 'Topic', callback=callback)
callback.args['topic1'] = topic_slider
topic_slider2 = Slider(start=1, end = ntopics, value=1, step=1, title = 'Topic', callback=callback)
callback.args['topic2'] = topic_slider2

url = "http://oracc.museum.upenn.edu/@id_text"

taptool = p.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(column(topic_slider, topic_slider2, p))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b497a7ea-41e3-4184-8075-89cda3352655"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b497a7ea-41e3-4184-8075-89cda3352655").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b497a7ea-41e3-4184-8075-89cda3352655");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b497a7ea-41e3-4184-8075-89cda3352655' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1ae93c6f-da63-4336-802d-4330011bb7ee":{"roots":{"references":[{"attributes":{"children":[{"id":"7af35c21-de9d-4cd6-b575-1b9de1b272b2","type":"Slider"}]},"id":"d22e4e93-f9dc-4f5b-8e2d-25a7b8226dae","type":"WidgetBox"},{"attributes":{},"id":"62a14fe8-dc57-4216-970c-c722a9b35087","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"110f3225-4db4-464b-82f9-13769788c787","subtype":"Figure","type":"Plot"},"ticker":{"id":"5c84d8bc-7936-4fc2-81f2-8f43c023f211","type":"BasicTicker"}},"id":"a5fc59e2-6d33-4057-a370-f07e02d9c1f6","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9c765253-9b9e-4208-83c0-1638ce0cac95","type":"TapTool"},{"id":"b988c670-7743-474a-8925-4bb33f410d7f","type":"PanTool"},{"id":"cb1744ea-e165-4fc9-820c-95ce4f355804","type":"WheelZoomTool"},{"id":"7c5749e9-27aa-4a06-a69a-e072cf220563","type":"BoxZoomTool"},{"id":"c9662f6f-9764-4841-a41f-92073f905fbb","type":"ResetTool"},{"id":"262475f7-c3b9-4085-ba1c-1e3f5c65782c","type":"SaveTool"},{"id":"9efccdb3-3435-4780-99d4-dc2327ed11c8","type":"HoverTool"}]},"id":"51af7645-6143-466a-8d54-036f75cb6b28","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"abba1a9b-6c87-4fa1-b9ec-4cb254bcbb6a","type":"Circle"},{"attributes":{"url":"http://oracc.museum.upenn.edu/@id_text"},"id":"f3e41acf-c29a-40a1-886b-7cd19f975c9c","type":"OpenURL"},{"attributes":{"children":[{"id":"2bc8ccaa-8372-4bee-ad9d-1047fb5e01ee","type":"Slider"}]},"id":"5f6596b9-304d-4728-bd8f-f04d188698ce","type":"WidgetBox"},{"attributes":{},"id":"5dabd4c5-f4ad-474c-9594-de230b9da96f","type":"BasicTickFormatter"},{"attributes":{"callback":{"id":"f3e41acf-c29a-40a1-886b-7cd19f975c9c","type":"OpenURL"},"plot":{"id":"110f3225-4db4-464b-82f9-13769788c787","subtype":"Figure","type":"Plot"}},"id":"9c765253-9b9e-4208-83c0-1638ce0cac95","type":"TapTool"},{"attributes":{"callback":{"id":"27a0029a-dcd4-4a39-9e0d-d9319e453875","type":"CustomJS"},"end":10,"start":1,"step":1,"title":"Topic","value":1},"id":"7af35c21-de9d-4cd6-b575-1b9de1b272b2","type":"Slider"},{"attributes":{"children":[{"id":"5f6596b9-304d-4728-bd8f-f04d188698ce","type":"WidgetBox"},{"id":"d22e4e93-f9dc-4f5b-8e2d-25a7b8226dae","type":"WidgetBox"},{"id":"110f3225-4db4-464b-82f9-13769788c787","subtype":"Figure","type":"Plot"}]},"id":"2e59a36d-a1a1-4394-b6bf-7514692f5abb","type":"Column"},{"attributes":{"callback":null},"id":"d23f43a0-784a-453c-ab21-18d361821c2f","type":"DataRange1d"},{"attributes":{"below":[{"id":"67681f65-a734-49b9-b2ce-0842db8da4cf","type":"LinearAxis"}],"left":[{"id":"d80c6f69-3b05-4698-a31b-dc30859e0c87","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"67681f65-a734-49b9-b2ce-0842db8da4cf","type":"LinearAxis"},{"id":"18d28a25-bab9-4981-a6e2-af4d8f40a70f","type":"Grid"},{"id":"d80c6f69-3b05-4698-a31b-dc30859e0c87","type":"LinearAxis"},{"id":"a5fc59e2-6d33-4057-a370-f07e02d9c1f6","type":"Grid"},{"id":"7d02c2fb-9dbb-45d3-ad78-2170954281c1","type":"BoxAnnotation"},{"id":"fa0eb061-250a-4618-bc2a-ffba263cc78c","type":"GlyphRenderer"}],"title":{"id":"7efea9be-f6d5-4726-8899-75133b6a4b91","type":"Title"},"tool_events":{"id":"62a14fe8-dc57-4216-970c-c722a9b35087","type":"ToolEvents"},"toolbar":{"id":"51af7645-6143-466a-8d54-036f75cb6b28","type":"Toolbar"},"x_range":{"id":"d23f43a0-784a-453c-ab21-18d361821c2f","type":"DataRange1d"},"y_range":{"id":"b2a7d9ad-2f90-4634-9fa4-579a84b3ba18","type":"DataRange1d"}},"id":"110f3225-4db4-464b-82f9-13769788c787","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode" ...

# %% [markdown]
# # TSNE based on Document/Topic Matrix

# %%
X = d_t_df.drop('text_name', axis=1).as_matrix()
tsne = TSNE(n_components = 2, init = 'pca', random_state=0)
X_tsne = tsne.fit_transform(X)

# %%
tsne2_x = [x for x, y in X_tsne]
tsne2_y = [y for x, y in X_tsne]

# %%
source_tsne2 = ColumnDataSource(data=dict(
        x=tsne2_x,
        y=tsne2_y,
        id_text=list(d_t_df.index.values),
        size = probability/max(probability)*25,
        probability = probability,
        topic = prevalent_topic,
        color = colors,
        orig_color = color_list,
        text_name = text_name
    ))

# %%
p = figure(
    plot_width=800, plot_height=800,
    tools="tap,pan,wheel_zoom,box_zoom,reset,save", 
    title="Topic Distribution tSNE.\nSize of the circle represents prevalence of the topic")
p.add_tools(HoverTool(
        tooltips=[
            ("url", "http://oracc.org/" + "@id_text"),
            (("topic, probability"), ("@topic, @probability")),
            ("text name", "@text_name")
        ]
        ))


p.circle('x', 'y', color='color', fill_alpha=0.5, size='size', source=source_tsne2)
p.axis.visible = False

callback = CustomJS(args=dict(source=source_tsne2), code = """
    var data = source.get('data');
    var current_topic_1 = topic1.value;
    var current_topic_2 = topic2.value;
    x = data['x']
    y = data['y']
    col = data['color']
    topic = data['topic']

    orig_color = data['orig_color']
    for (i = 0; i < x.length; i++) {
        if (topic[i].substring(6) == current_topic_1) {
            col[i] = orig_color[current_topic_1 - 1]
        } else {
            col[i] = 'grey'
        }
        if (topic[i].substring(6) == current_topic_2) {
            col[i] = orig_color[current_topic_2 - 1]
        }
    }
    source.trigger('change');
""")

topic_slider = Slider(start=1, end = ntopics, value=1, step=1, title = 'Topic', callback=callback)
callback.args['topic1'] = topic_slider
topic_slider2 = Slider(start=1, end = ntopics, value=1, step=1, title = 'Topic', callback=callback)
callback.args['topic2'] = topic_slider2

url = "http://oracc.museum.upenn.edu/@id_text"

taptool = p.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(column(topic_slider, topic_slider2, p))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="094d924d-5572-4c97-b331-08624101ef17"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#094d924d-5572-4c97-b331-08624101ef17").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("094d924d-5572-4c97-b331-08624101ef17");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '094d924d-5572-4c97-b331-08624101ef17' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d96e7ba5-fb55-410f-9db4-a22413591ba6":{"roots":{"references":[{"attributes":{"formatter":{"id":"b4729208-1f4c-4477-8316-823471e336af","type":"BasicTickFormatter"},"plot":{"id":"744629b2-1474-4924-b8ab-4ad6da71282b","subtype":"Figure","type":"Plot"},"ticker":{"id":"d78634c6-b9bc-4867-83c8-dd8fb5809c7d","type":"BasicTicker"},"visible":false},"id":"a803050e-5a9c-4dce-9ad7-e025a6af02e3","type":"LinearAxis"},{"attributes":{"callback":null},"id":"f4c7d36d-e6db-4875-8a48-ad7f19578873","type":"DataRange1d"},{"attributes":{"data_source":{"id":"50a847de-10ff-41a4-ba56-69c4dd18a0d9","type":"ColumnDataSource"},"glyph":{"id":"49cc26de-9426-4b49-9c43-ce55f5f10e43","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"c6b31499-81fe-4f2a-a970-3ee43c55a3b8","type":"Circle"},"selection_glyph":null},"id":"df819f7c-9f90-43ff-9969-b347f8616cda","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_color":{"field":"color"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"49cc26de-9426-4b49-9c43-ce55f5f10e43","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5dff24c6-1822-47e0-a43b-9a6b7ba96ef1","type":"TapTool"},{"id":"f768ba0a-f199-49af-a34c-1dca9eac52e6","type":"PanTool"},{"id":"292de952-0698-4ccc-8ed9-5a465b301d00","type":"WheelZoomTool"},{"id":"c301153e-8bd8-48a8-a4d5-dc52cc1a0a07","type":"BoxZoomTool"},{"id":"d8eb496a-d742-4c18-8145-012c8a281585","type":"ResetTool"},{"id":"9dea22f2-11a4-42dc-be1b-08e5145c23af","type":"SaveTool"},{"id":"20a850a4-cf1c-404b-9e15-6f53e88d62f5","type":"HoverTool"}]},"id":"5e2cf0df-a175-4bfe-8dd7-738203f8a032","type":"Toolbar"},{"attributes":{"formatter":{"id":"d0971dd9-99dd-4fb8-886e-6e1e09d33bbe","type":"BasicTickFormatter"},"plot":{"id":"744629b2-1474-4924-b8ab-4ad6da71282b","subtype":"Figure","type":"Plot"},"ticker":{"id":"911172f6-a50d-490a-90d6-717383a0d406","type":"BasicTicker"},"visible":false},"id":"a3dcb70c-11fb-4e2c-bdc7-f047e79aed2c","type":"LinearAxis"},{"attributes":{"callback":{"id":"85495534-5ded-40f9-9472-df41fb12efc2","type":"OpenURL"},"plot":{"id":"744629b2-1474-4924-b8ab-4ad6da71282b","subtype":"Figure","type":"Plot"}},"id":"5dff24c6-1822-47e0-a43b-9a6b7ba96ef1","type":"TapTool"},{"attributes":{},"id":"d78634c6-b9bc-4867-83c8-dd8fb5809c7d","type":"BasicTicker"},{"attributes":{"plot":{"id":"744629b2-1474-4924-b8ab-4ad6da71282b","subtype":"Figure","type":"Plot"}},"id":"9dea22f2-11a4-42dc-be1b-08e5145c23af","type":"SaveTool"},{"attributes":{"callback":null},"id":"a40caa43-1482-4b68-b4c1-bf8307a85803","type":"DataRange1d"},{"attributes":{},"id":"b4729208-1f4c-4477-8316-823471e336af","type":"BasicTickFormatter"},{"attributes":{"callback":{"id":"e46bd8b5-2b8f-498e-94d9-6d6e122da057","type":"CustomJS"},"end":10,"start":1,"step":1,"title":"Topic","value":1},"id":"e8850b0b-e1cf-425a-91f0-dba3f7f4f0ca","type":"Slider"},{"attributes":{"callback":null,"column_names":["y","id_text","color","size","text_name","orig_color","topic","x","probability"],"data":{"color":["green","firebrick","olive","fuchsia","aqua","olive","red","green","blue","fuchsia","fuchsia","fuchsia","fuchsia","fuchsia","fuchsia","fuchsia","fuchsia","green","blue","olive","firebrick","fuchsia","gold","green","fuchsia","red","fuchsia","green","firebrick","red","firebrick","green","green","green","green","olive","aqua","green","firebrick","red","gold","fuchsia","fuchsia","fuchsia","green","green","green","red","gold","red","fuchsia","aqua","red","blue","fuchsia","aqua","red","fuchsia","fuchsia","blue","red","gold","olive","fuchsia","olive","gold","green","green","green","purple","red","green","green","green","green","red","purple","green","firebrick","green","purple","green","aqua","fuchsia","red","purple","firebrick","fuchsia","firebrick","red","red","aqua","blue","fuchsia","olive","green","olive","green","green","fuchsia","green","red","purple","green","fuchsia ...
